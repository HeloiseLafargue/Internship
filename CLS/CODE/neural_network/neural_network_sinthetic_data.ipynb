# %% [markdown]
# ## Réseau à modèles imbriqués

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import time

# %% [markdown]
# ## True function

# %%
def function(v1, v2):
    a1 = -0.04
    a2 = 0.002
    a3 = -0.002
    a4 = 8*(1e-5)
    return v2 * (a1 + a2 * v2 + a3 * v1 + a4 * (v1 ** 2))

# Créer une grille de valeurs pour x1 et x2
v1_values = np.linspace(0, 20, 100)
v2_values = np.linspace(0, 12, 100)
v1_grid, v2_grid = np.meshgrid(v1_values, v2_values)

# Calculer les valeurs de y pour chaque combinaison de x1 et x2
y_grid = function(v1_grid, v2_grid)

# Tracer les résultats avec une colorbar continue
plt.figure(figsize=(10, 6))
cp = plt.contourf(v1_grid, v2_grid, y_grid, cmap='viridis', levels=100)
cbar = plt.colorbar(cp)
cbar.ax.set_ylabel('Valeur de la fonction BM4')

# Ajouter des courbes de niveaux
contours = plt.contour(v1_grid, v2_grid, y_grid, colors='white', levels=10)
plt.clabel(contours, inline=True, fontsize=8)

plt.xlabel('WS (m.s-1)')
plt.ylabel('SWH (m)')
plt.title('Représentation de la fonction BM4 du SSB')
plt.show()

# %% [markdown]
# ## True dataset

# %%
# Spécifiez le chemin du fichier .dat dans votre Google Drive
file_path = '/data/SSB_ETU/HLAFARGUE/DATASET_NGAN/dataset_equal_tirage1perbox.dat'
#file_path = '/data/SSB_ETU/HLAFARGUE/DATASET_NGAN/dataset_tirage_random_parcyc.dat'

# Chargement du fichier .dat dans un DataFrame
data = pd.read_csv(file_path, sep='\s+', header=None)
column_names = ['SWH2', 'WS2', 'SWH1', 'WS1', 'Delta_SSH']
data.columns = column_names

# Affichage des premières lignes du DataFrame avec les noms de colonnes
print(data.head())
# Out:
#     SWH2    WS2   SWH1     WS1  Delta_SSH
# 0  0.732  0.120  2.550   9.715      0.032
# 1  0.966  0.161  3.450  11.929      0.100
# 2  1.145  0.097  1.301   4.275      0.053
# 3  1.424  0.128  1.350   5.737     -0.031
# 4  1.524  0.122  1.381   1.982     -0.011

# %%
data.describe()
# Out:
#                SWH2           WS2          SWH1           WS1     Delta_SSH
# count  56744.000000  56744.000000  56744.000000  56744.000000  56744.000000
# mean       4.145546     10.317656      3.259200      9.065882     -0.024338
# std        2.084666      5.438556      1.549936      3.976422      0.100945
# min        0.052000      0.003000      0.087000      0.005000     -0.499000
# 25%        2.516750      5.939750      2.109000      6.149000     -0.083000
# 50%        4.021000     10.262000      3.041000      8.691000     -0.021000
# 75%        5.659000     14.753000      4.183000     11.627000      0.037000
# max       10.879000     20.999000     10.798000     20.993000      0.496000

# %%
# Déterminer les limites des données pour définir les boîtes de 0.25x0.25
x_min, x_max = data['WS2'].min(), data['WS2'].max()
y_min, y_max = data['SWH2'].min(), data['SWH2'].max()

# Créer les bin edges avec des intervalles de 0.25
x_bins = np.arange(x_min, x_max + 0.25, 0.25)
y_bins = np.arange(y_min, y_max + 0.25, 0.25)

# Créer les histogrammes 2D avec les boîtes de 0.25x0.25
plt.figure(figsize=(14, 6))

# Histogramme 2D pour WS2 et SWH2
plt.subplot(1, 2, 1)
plt.hist2d(data['WS2'], data['SWH2'], bins=[x_bins, y_bins], cmap='Blues', vmax=100)
plt.colorbar()
plt.xlabel('WS2')
plt.ylabel('SWH2')
plt.title('Histogramme 2D de WS2 et SWH2')

# Déterminer les limites des données pour SWH1 et WS1
x_min, x_max = data['WS1'].min(), data['WS1'].max()
y_min, y_max = data['SWH1'].min(), data['SWH1'].max()

# Créer les bin edges avec des intervalles de 0.25
x_bins = np.arange(x_min, x_max + 0.25, 0.25)
y_bins = np.arange(y_min, y_max + 0.25, 0.25)

# Histogramme 2D pour WS1 et SWH1
plt.subplot(1, 2, 2)
plt.hist2d(data['WS1'], data['SWH1'], bins=[x_bins, y_bins], cmap='Blues', vmax=100)
plt.colorbar()
plt.xlabel('WS1')
plt.ylabel('SWH1')
plt.title('Histogramme 2D de WS1 et SWH1')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prepare data

# %%
# Créer les nouvelles DataFrames X1 et X2
X1 = data[['WS1', 'SWH1']]
X2 = data[['WS2', 'SWH2']]

# Affichage des premières lignes de X1 et X2 pour vérifier
print("X1:")
print(X1.head())

print("X2:")
print(X2.head())
# Out:
# X1:
#       WS1   SWH1
# 0   9.715  2.550
# 1  11.929  3.450
# 2   4.275  1.301
# 3   5.737  1.350
# 4   1.982  1.381
# X2:
#      WS2   SWH2
# 0  0.120  0.732
# 1  0.161  0.966
# 2  0.097  1.145
# 3  0.128  1.424
# 4  0.122  1.524

# %%
# Calculer Delta_ssh_model
Delta_ssh_model = function(X2['WS2'].values, X2['SWH2'].values) - function(X1['WS1'].values, X1['SWH1'].values)
#Delta_ssh_model = data[['Delta_SSH']].values

# Calculer w_init1
w_init1 = function(X2['WS2'].values, X2['SWH2'].values)

# %%
## Assuming X2 is a DataFrame with columns 'WS2' and 'SWH2'
#WS_values = X2['WS2'].values
#SWH_values = X2['SWH2'].values

## Create a meshgrid
#WS, SWH = np.meshgrid(WS_values, SWH_values)

## Define the function to calculate w_init
#def w_init(WS, SWH):
#    return 1.01 * WS + 1.02 * SWH  

## Compute w_init1 on the meshgrid
#w_init1 = w_init(WS, SWH)

## Plot the results with a continuous colorbar
#plt.figure(figsize=(10, 6))
#cp = plt.contourf(WS, SWH, w_init1, cmap='viridis', levels=100)
#cbar = plt.colorbar(cp)
#cbar.ax.set_ylabel('Valeur de w_init1')

## Add contour lines
#contours = plt.contour(WS, SWH, w_init1, colors='white', levels=10)
#plt.clabel(contours, inline=True, fontsize=8)

#plt.xlabel('WS (m.s-1)')
#plt.ylabel('SWH (m)')
#plt.title('Représentation de w_init1')
#plt.show()

# %%
class CustomDataset(Dataset):
    def __init__(self, X1, X2, Delta_ssh_model, w_init1):
        self.X1 = torch.tensor(X1, dtype=torch.float32)
        self.X2 = torch.tensor(X2, dtype=torch.float32)
        self.Delta_ssh_model = torch.tensor(Delta_ssh_model, dtype=torch.float32)
        self.w_init1 = torch.tensor(w_init1, dtype=torch.float32)

    def __len__(self):
        return len(self.X1)

    def __getitem__(self, idx):
        return {
            'X1': self.X1[idx],
            'X2': self.X2[idx],
            'Delta_ssh_model': self.Delta_ssh_model[idx],
            'w_init1': self.w_init1[idx]
        }

# %%
def prepare_data_train_val_test(X1, X2, Delta_ssh_model, w_init1, batch_size=32):
    # Standardiser les données
    scaler1 = StandardScaler()
    X1_scaled = scaler1.fit_transform(X1)
    scaler2 = StandardScaler()
    X2_scaled = scaler2.fit_transform(X2)

    mean_1, scale_1 = scaler1.mean_, scaler1.scale_
    mean_2, scale_2 = scaler2.mean_, scaler2.scale_

    # Diviser les données en ensembles d'entraînement, de validation et de test
    X1_train, X1_temp, X2_train, X2_temp, Delta_train, Delta_temp, w_train, w_temp = train_test_split(
        X1_scaled, X2_scaled, Delta_ssh_model, w_init1, test_size=0.3, random_state=42)

    X1_val, X1_test, X2_val, X2_test, Delta_val, Delta_test, w_val, w_test = train_test_split(
        X1_temp, X2_temp, Delta_temp, w_temp, test_size=0.5, random_state=42)

    # Créer les datasets PyTorch
    train_dataset = CustomDataset(X1_train, X2_train, Delta_train, w_train)
    val_dataset = CustomDataset(X1_val, X2_val, Delta_val, w_val)
    test_dataset = CustomDataset(X1_test, X2_test, Delta_test, w_test)

    # Créer les DataLoaders PyTorch
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader, mean_1, scale_1, mean_2, scale_2

# Préparer les DataLoaders
train_loader, val_loader, test_loader, mean_1, scale_1, mean_2, scale_2 = prepare_data_train_val_test(X1, X2, Delta_ssh_model, w_init1, batch_size=32)

# Afficher les formes des ensembles pour vérification
print("Nombre de batchs dans train_loader:", len(train_loader))
print("Nombre de batchs dans val_loader:", len(val_loader))
print("Nombre de batchs dans test_loader:", len(test_loader))
# Out:
# Nombre de batchs dans train_loader: 1242
# Nombre de batchs dans val_loader: 266
# Nombre de batchs dans test_loader: 266

# %%
def prepare_all_data(X1, X2, Delta_ssh_model, w_init1, batch_size=32):
    # Standardiser les données
    scaler1 = StandardScaler()
    X1_scaled = scaler1.fit_transform(X1)
    scaler2 = StandardScaler()
    X2_scaled = scaler2.fit_transform(X2)

    mean_1, scale_1 = scaler1.mean_, scaler1.scale_
    mean_2, scale_2 = scaler2.mean_, scaler2.scale_

    # Créer le dataset PyTorch
    all_dataset = CustomDataset(X1_scaled, X2_scaled, Delta_ssh_model, w_init1)

    # Créer les DataLoaders PyTorch
    loader = DataLoader(all_dataset, batch_size=batch_size, shuffle=True)

    return loader, mean_1, scale_1, mean_2, scale_2

# Préparer le DataLoader
loader, mean_1, scale_1, mean_2, scale_2 = prepare_all_data(X1, X2, Delta_ssh_model, w_init1, batch_size=32)

# %%
# en train-test-val 

train_loader, val_loader, test_loader, mean_1, scale_1, mean_2, scale_2 = prepare_data_train_val_test(X1, X2, Delta_ssh_model, w_init1, batch_size=32)

# %% [markdown]
# ## Model definition

# %%
class SubModel(nn.Module):
    def __init__(self, input_dim):
        super(SubModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 16)
        #self.layer2 = nn.Linear(64, 32)
        self.output = nn.Linear(16, 1)

    def forward(self, x):
        x = torch.tanh(self.layer1(x))
        #x = torch.tanh(self.layer2(x))
        x = self.output(x)
        return x

class ParallelModel(nn.Module):
    def __init__(self, nb_var):
        super(ParallelModel, self).__init__()
        self.submodel1 = SubModel(nb_var)
        self.submodel2 = SubModel(nb_var)

    def forward(self, X1, X2):
        y1 = self.submodel1(X1)
        y2 = self.submodel2(X2)
        return y1, y2

# %%
nb_var = 2
model = ParallelModel(nb_var)
print(model)
# Out:
# ParallelModel(
#   (submodel1): SubModel(
#     (layer1): Linear(in_features=2, out_features=16, bias=True)
#     (output): Linear(in_features=16, out_features=1, bias=True)
#   )
#   (submodel2): SubModel(
#     (layer1): Linear(in_features=2, out_features=16, bias=True)
#     (output): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        # Xavier initialization for the weights
        nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
        # Constant initialization for the biases
        if m.bias is not None:
            nn.init.constant_(m.bias, 0.0)

# %% [markdown]
# Explication
#
# - Type de Couche :
#
# La fonction vérifie si le module passé (m) est une couche linéaire (nn.Linear). Si c'est le cas, elle applique une initialisation spécifique aux poids et aux biais de cette couche.
#
#
# - Initialisation Xavier (He) des Poids :
#
# nn.init.kaiming_uniform_ : Il s'agit d'une initialisation basée sur la méthode He (ou Kaiming), qui initialise les poids selon une distribution uniforme.
#
# Cette méthode est particulièrement adaptée pour les réseaux utilisant des fonctions d'activation ReLU (Rectified Linear Unit). Elle aide à maintenir la variance des gradients à travers les couches, ce qui permet un entraînement plus stable et plus rapide.
#
# L'argument nonlinearity='relu' indique que cette initialisation est optimisée pour les activations de type ReLU.
#
#
# - Initialisation Constante des Biais :
#
# nn.init.constant_ : Cette fonction initialise les biais à une valeur constante, ici 0.0.
#
# Initialiser les biais à zéro est une pratique courante qui simplifie l'apprentissage, car cela n'introduit pas de biais initial dans les activations des neurones.

# %% [markdown]
# ## Training and validation

# %%
# Initialiser le modèle, les optimiseurs et la perte
nb_var = 2
model = ParallelModel(nb_var)
model.apply(init_weights)
learning_rate = 0.05
optimizer1 = optim.SGD(model.submodel1.parameters(), lr=learning_rate)
optimizer2 = optim.SGD(model.submodel2.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

# %% [markdown]
# #### Version avec critère de convergence par phase

# %%
import time

# Listes pour enregistrer les valeurs de perte
train_losses1 = []
train_losses2 = []

# Listes pour enregistrer les valeurs de perte
train_losses1_phase1 = []
train_losses2_phase2 = []
train_losses1_phase3 = []
train_losses2_phase3 = []

# Critères de convergence
stop_criteria1 = 1e-6
stop_criteria2 = 1e-6
stop_criteria_alternated = 1e-6

# Variables pour les temps et les compteurs d'époques
start_time = time.time()
epoch_phase1 = 0
epoch_phase2 = 0
epoch_phase3 = 0

# Phase 1
while True:
    model.train()
    epoch_loss1 = 0
    for batch in loader:
        X1 = batch['X1']
        X2 = batch['X2']
        delta_ssh = batch['Delta_ssh_model']
        w_init1 = batch['w_init1']

        y1, _ = model(X1, X2)
        optimizer1.zero_grad()
        loss1 = criterion(delta_ssh.unsqueeze(1), w_init1.unsqueeze(1) - y1)
        loss1.backward(retain_graph=True)
        optimizer1.step()
        epoch_loss1 += loss1.item()
    
    avg_train_loss1 = epoch_loss1 / len(loader)
    train_losses1.append(avg_train_loss1)
    train_losses1_phase1.append(avg_train_loss1)
    epoch_phase1 += 1
    print(f'Phase 1 - Epoch [{epoch_phase1}], Train Loss1: {avg_train_loss1:.8f}')
    
    if avg_train_loss1 < stop_criteria1:
        print(f'Phase 1 completed at epoch {epoch_phase1} as Train Loss1 reached {avg_train_loss1:.8f}')
        break

# Phase 2
while True:
    model.train()
    epoch_loss2 = 0
    for batch in loader:
        X1 = batch['X1']
        X2 = batch['X2']
        delta_ssh = batch['Delta_ssh_model']

        y1, y2 = model(X1, X2)
        optimizer2.zero_grad()
        loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
        loss2.backward()
        optimizer2.step()
        epoch_loss2 += loss2.item()
    
    avg_train_loss2 = epoch_loss2 / len(loader)
    train_losses2_phase2.append(avg_train_loss2)
    epoch_phase2 += 1
    print(f'Phase 2 - Epoch [{epoch_phase2}], Train Loss2: {avg_train_loss2:.8f}')
    
    if avg_train_loss2 < stop_criteria2:
        print(f'Phase 2 completed at epoch {epoch_phase2} as Train Loss2 reached {avg_train_loss2:.8f}')
        break

# Phase 3
while True:
    model.train()
    epoch_loss1 = 0
    epoch_loss2 = 0
    for batch in loader:
        X1 = batch['X1']
        X2 = batch['X2']
        delta_ssh = batch['Delta_ssh_model']

        # Forward pass for both sub-models
        y1, y2 = model(X1, X2)

        # Calcul de la perte pour SubModel1
        optimizer1.zero_grad()
        loss1 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
        loss1.backward(retain_graph=True)
        optimizer1.step()
        epoch_loss1 += loss1.item()

        # Forward pass for both sub-models
        y1, y2 = model(X1, X2)
        # Calcul de la perte pour SubModel2
        optimizer2.zero_grad()
        loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
        loss2.backward()
        optimizer2.step()
        epoch_loss2 += loss2.item()
    
    avg_train_loss1 = epoch_loss1 / len(loader)
    avg_train_loss2 = epoch_loss2 / len(loader)
    train_losses1_phase3.append(avg_train_loss1)
    train_losses2_phase3.append(avg_train_loss2)
    epoch_phase3 += 1
    print(f'Phase 3 - Epoch [{epoch_phase3}], Train Loss1: {avg_train_loss1:.8f}, Train Loss2: {avg_train_loss2:.8f}')
    
    if avg_train_loss1 < stop_criteria_alternated and avg_train_loss2 < stop_criteria_alternated:
        print(f'Phase 3 completed at epoch {epoch_phase3} as both Train Loss1 and Train Loss2 reached {avg_train_loss1:.8f} and {avg_train_loss2:.8f} respectively')
        break

end_time = time.time()
total_time = end_time - start_time

print(f'Total training time: {total_time:.2f} seconds')
print(f'Number of epochs for phase 1 (initialization): {epoch_phase1}')
print(f'Number of epochs for phase 2: {epoch_phase2}')
print(f'Number of epochs for phase 3 (alternating): {epoch_phase3}')

## Validation
# model.eval()
# val_loss1 = 0
# val_loss2 = 0
# with torch.no_grad():
#     for batch in val_loader:
#         X1 = batch['X1']
#         X2 = batch['X2']
#         delta_ssh = batch['Delta_ssh_model']
#         y1, y2 = model(X1, X2)
#         loss1 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
#         loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
#         val_loss1 += loss1.item()
#         val_loss2 += loss2.item()

# avg_val_loss1 = val_loss1 / len(val_loader)
# avg_val_loss2 = val_loss2 / len(val_loader)
# val_losses1.append(avg_val_loss1)
# val_losses2.append(avg_val_loss2)
# print(f'Epoch [{epoch+1}/{num_epochs}], Val Loss1: {avg_val_loss1:.4f}, Val Loss2: {avg_val_loss2:.4f}')
# Out:
# Phase 1 - Epoch [1], Train Loss1: 0.00490306
# Phase 1 - Epoch [2], Train Loss1: 0.00049975
# Phase 1 - Epoch [3], Train Loss1: 0.00028754
# Phase 1 - Epoch [4], Train Loss1: 0.00021632
# Phase 1 - Epoch [5], Train Loss1: 0.00017524
# Phase 1 - Epoch [6], Train Loss1: 0.00014784
# Phase 1 - Epoch [7], Train Loss1: 0.00012796
# Phase 1 - Epoch [8], Train Loss1: 0.00011341
# Phase 1 - Epoch [9], Train Loss1: 0.00010232
# Phase 1 - Epoch [10], Train Loss1: 0.00009364
# Phase 1 completed at epoch 10 as Train Loss1 reached 0.00009364
# Phase 2 - Epoch [1], Train Loss2: 0.00885758
# Phase 2 - Epoch [2], Train Loss2: 0.00161042
# Phase 2 - Epoch [3], Train Loss2: 0.00074796
# Phase 2 - Epoch [4], Train Loss2: 0.00044314
# Phase 2 - Epoch [5], Train Loss2: 0.00032280
# Phase 2 - Epoch [6], Train Loss2: 0.00026947
# Phase 2 - Epoch [7], Train Loss2: 0.00024251
# Phase 2 - Epoch [8], Train Loss2: 0.00022648
# Phase 2 - Epoch [9], Train Loss2: 0.00021583
# Phase 2 - Epoch [10], Train Loss2: 0.00020792
# Phase 2 - Epoch [11], Train Loss2: 0.00020110
# Phase 2 - Epoch [12], Train Loss2: 0.00019545
# Phase 2 - Epoch [13], Train Loss2: 0.00019061
# Phase 2 - Epoch [14], Train Loss2: 0.00018613
# Phase 2 - Epoch [15], Train Loss2: 0.00018202
# Phase 2 - Epoch [16], Train Loss2: 0.00017851
# Phase 2 - Epoch [17], Train Loss2: 0.00017508
# Phase 2 - Epoch [18], Train Loss2: 0.00017187
# Phase 2 - Epoch [19], Train Loss2: 0.00016892
# Phase 2 - Epoch [20], Train Loss2: 0.00016619
# Phase 2 - Epoch [21], Train Loss2: 0.00016348
# Phase 2 - Epoch [22], Train Loss2: 0.00016105
# Phase 2 - Epoch [23], Train Loss2: 0.00015874
# Phase 2 - Epoch [24], Train Loss2: 0.00015642
# Phase 2 - Epoch [25], Train Loss2: 0.00015443
# Phase 2 - Epoch [26], Train Loss2: 0.00015240
# Phase 2 - Epoch [27], Train Loss2: 0.00015056
# Phase 2 - Epoch [28], Train Loss2: 0.00014887
# Phase 2 - Epoch [29], Train Loss2: 0.00014716
# Phase 2 - Epoch [30], Train Loss2: 0.00014555
# Phase 2 - Epoch [31], Train Loss2: 0.00014401
# Phase 2 - Epoch [32], Train Loss2: 0.00014252
# Phase 2 - Epoch [33], Train Loss2: 0.00014112
# Phase 2 - Epoch [34], Train Loss2: 0.00013980
# Phase 2 - Epoch [35], Train Loss2: 0.00013853
# Phase 2 - Epoch [36], Train Loss2: 0.00013742
# Phase 2 - Epoch [37], Train Loss2: 0.00013611
# Phase 2 - Epoch [38], Train Loss2: 0.00013510
# Phase 2 - Epoch [39], Train Loss2: 0.00013395
# Phase 2 - Epoch [40], Train Loss2: 0.00013290
# Phase 2 - Epoch [41], Train Loss2: 0.00013197
# Phase 2 - Epoch [42], Train Loss2: 0.00013114
# Phase 2 - Epoch [43], Train Loss2: 0.00013010
# Phase 2 - Epoch [44], Train Loss2: 0.00012919
# Phase 2 - Epoch [45], Train Loss2: 0.00012832
# Phase 2 - Epoch [46], Train Loss2: 0.00012763
# Phase 2 - Epoch [47], Train Loss2: 0.00012687
# Phase 2 - Epoch [48], Train Loss2: 0.00012599
# Phase 2 - Epoch [49], Train Loss2: 0.00012533
# Phase 2 - Epoch [50], Train Loss2: 0.00012464
# Phase 2 - Epoch [51], Train Loss2: 0.00012394
# Phase 2 - Epoch [52], Train Loss2: 0.00012333
# Phase 2 - Epoch [53], Train Loss2: 0.00012268
# Phase 2 - Epoch [54], Train Loss2: 0.00012210
# Phase 2 - Epoch [55], Train Loss2: 0.00012152
# Phase 2 - Epoch [56], Train Loss2: 0.00012089
# Phase 2 - Epoch [57], Train Loss2: 0.00012041
# Phase 2 - Epoch [58], Train Loss2: 0.00011996
# Phase 2 - Epoch [59], Train Loss2: 0.00011937
# Phase 2 - Epoch [60], Train Loss2: 0.00011894
# Phase 2 - Epoch [61], Train Loss2: 0.00011838
# Phase 2 - Epoch [62], Train Loss2: 0.00011802
# Phase 2 - Epoch [63], Train Loss2: 0.00011749
# Phase 2 - Epoch [64], Train Loss2: 0.00011705
# Phase 2 - Epoch [65], Train Loss2: 0.00011661
# Phase 2 - Epoch [66], Train Loss2: 0.00011618
# Phase 2 - Epoch [67], Train Loss2: 0.00011583
# Phase 2 - Epoch [68], Train Loss2: 0.00011546
# Phase 2 - Epoch [69], Train Loss2: 0.00011510
# Phase 2 - Epoch [70], Train Loss2: 0.00011476
# Phase 2 - Epoch [71], Train Loss2: 0.00011425
# Phase 2 - Epoch [72], Train Loss2: 0.00011398
# Phase 2 - Epoch [73], Train Loss2: 0.00011365
# Phase 2 - Epoch [74], Train Loss2: 0.00011338
# Phase 2 - Epoch [75], Train Loss2: 0.00011304
# Phase 2 - Epoch [76], Train Loss2: 0.00011273
# Phase 2 - Epoch [77], Train Loss2: 0.00011242
# Phase 2 - Epoch [78], Train Loss2: 0.00011206
# Phase 2 - Epoch [79], Train Loss2: 0.00011182
# Phase 2 - Epoch [80], Train Loss2: 0.00011153
# Phase 2 - Epoch [81], Train Loss2: 0.00011124
# Phase 2 - Epoch [82], Train Loss2: 0.00011095
# Phase 2 - Epoch [83], Train Loss2: 0.00011079
# Phase 2 - Epoch [84], Train Loss2: 0.00011056
# Phase 2 - Epoch [85], Train Loss2: 0.00011025
# Phase 2 - Epoch [86], Train Loss2: 0.00011005
# Phase 2 - Epoch [87], Train Loss2: 0.00010971
# Phase 2 - Epoch [88], Train Loss2: 0.00010956
# Phase 2 - Epoch [89], Train Loss2: 0.00010937
# Phase 2 - Epoch [90], Train Loss2: 0.00010912
# Phase 2 - Epoch [91], Train Loss2: 0.00010893
# Phase 2 - Epoch [92], Train Loss2: 0.00010870
# Phase 2 - Epoch [93], Train Loss2: 0.00010853
# Phase 2 - Epoch [94], Train Loss2: 0.00010827
# Phase 2 - Epoch [95], Train Loss2: 0.00010813
# Phase 2 - Epoch [96], Train Loss2: 0.00010804
# Phase 2 - Epoch [97], Train Loss2: 0.00010777
# Phase 2 - Epoch [98], Train Loss2: 0.00010762
# Phase 2 - Epoch [99], Train Loss2: 0.00010765
# Phase 2 - Epoch [100], Train Loss2: 0.00010718
# Phase 2 - Epoch [101], Train Loss2: 0.00010702
# Phase 2 - Epoch [102], Train Loss2: 0.00010690
# Phase 2 - Epoch [103], Train Loss2: 0.00010666
# Phase 2 - Epoch [104], Train Loss2: 0.00010652
# Phase 2 - Epoch [105], Train Loss2: 0.00010639
# Phase 2 - Epoch [106], Train Loss2: 0.00010631
# Phase 2 - Epoch [107], Train Loss2: 0.00010609
# Phase 2 - Epoch [108], Train Loss2: 0.00010592
# Phase 2 - Epoch [109], Train Loss2: 0.00010577
# Phase 2 - Epoch [110], Train Loss2: 0.00010575
# Phase 2 - Epoch [111], Train Loss2: 0.00010549
# Phase 2 - Epoch [112], Train Loss2: 0.00010536
# Phase 2 - Epoch [113], Train Loss2: 0.00010527
# Phase 2 - Epoch [114], Train Loss2: 0.00010512
# Phase 2 - Epoch [115], Train Loss2: 0.00010494
# Phase 2 - Epoch [116], Train Loss2: 0.00010498
# Phase 2 - Epoch [117], Train Loss2: 0.00010474
# Phase 2 - Epoch [118], Train Loss2: 0.00010462
# Phase 2 - Epoch [119], Train Loss2: 0.00010454
# Phase 2 - Epoch [120], Train Loss2: 0.00010442
# Phase 2 - Epoch [121], Train Loss2: 0.00010426
# Phase 2 - Epoch [122], Train Loss2: 0.00010415
# Phase 2 - Epoch [123], Train Loss2: 0.00010409
# Phase 2 - Epoch [124], Train Loss2: 0.00010397
# Phase 2 - Epoch [125], Train Loss2: 0.00010384
# Phase 2 - Epoch [126], Train Loss2: 0.00010372
# Phase 2 - Epoch [127], Train Loss2: 0.00010365
# Phase 2 - Epoch [128], Train Loss2: 0.00010354
# Phase 2 - Epoch [129], Train Loss2: 0.00010346
# Phase 2 - Epoch [130], Train Loss2: 0.00010334
# Phase 2 - Epoch [131], Train Loss2: 0.00010321
# Phase 2 - Epoch [132], Train Loss2: 0.00010309
# Phase 2 - Epoch [133], Train Loss2: 0.00010305
# Phase 2 - Epoch [134], Train Loss2: 0.00010300
# Phase 2 - Epoch [135], Train Loss2: 0.00010288
# Phase 2 - Epoch [136], Train Loss2: 0.00010283
# Phase 2 - Epoch [137], Train Loss2: 0.00010265
# Phase 2 - Epoch [138], Train Loss2: 0.00010257
# Phase 2 - Epoch [139], Train Loss2: 0.00010254
# Phase 2 - Epoch [140], Train Loss2: 0.00010243
# Phase 2 - Epoch [141], Train Loss2: 0.00010229
# Phase 2 - Epoch [142], Train Loss2: 0.00010230
# Phase 2 - Epoch [143], Train Loss2: 0.00010219
# Phase 2 - Epoch [144], Train Loss2: 0.00010210
# Phase 2 - Epoch [145], Train Loss2: 0.00010209
# Phase 2 - Epoch [146], Train Loss2: 0.00010194
# Phase 2 - Epoch [147], Train Loss2: 0.00010185
# Phase 2 - Epoch [148], Train Loss2: 0.00010184
# Phase 2 - Epoch [149], Train Loss2: 0.00010175
# Phase 2 - Epoch [150], Train Loss2: 0.00010165
# Phase 2 - Epoch [151], Train Loss2: 0.00010169
# Phase 2 - Epoch [152], Train Loss2: 0.00010154
# Phase 2 - Epoch [153], Train Loss2: 0.00010144
# Phase 2 - Epoch [154], Train Loss2: 0.00010137
# Phase 2 - Epoch [155], Train Loss2: 0.00010132
# Phase 2 - Epoch [156], Train Loss2: 0.00010142
# Phase 2 - Epoch [157], Train Loss2: 0.00010121
# Phase 2 - Epoch [158], Train Loss2: 0.00010112
# Phase 2 - Epoch [159], Train Loss2: 0.00010112
# Phase 2 - Epoch [160], Train Loss2: 0.00010101
# Phase 2 - Epoch [161], Train Loss2: 0.00010097
# Phase 2 - Epoch [162], Train Loss2: 0.00010091
# Phase 2 - Epoch [163], Train Loss2: 0.00010083
# Phase 2 - Epoch [164], Train Loss2: 0.00010076
# Phase 2 - Epoch [165], Train Loss2: 0.00010074
# Phase 2 - Epoch [166], Train Loss2: 0.00010063
# Phase 2 - Epoch [167], Train Loss2: 0.00010062
# Phase 2 - Epoch [168], Train Loss2: 0.00010054
# Phase 2 - Epoch [169], Train Loss2: 0.00010053
# Phase 2 - Epoch [170], Train Loss2: 0.00010041
# Phase 2 - Epoch [171], Train Loss2: 0.00010045
# Phase 2 - Epoch [172], Train Loss2: 0.00010034
# Phase 2 - Epoch [173], Train Loss2: 0.00010026
# Phase 2 - Epoch [174], Train Loss2: 0.00010023
# Phase 2 - Epoch [175], Train Loss2: 0.00010020
# Phase 2 - Epoch [176], Train Loss2: 0.00010019
# Phase 2 - Epoch [177], Train Loss2: 0.00010017
# Phase 2 - Epoch [178], Train Loss2: 0.00010013
# Phase 2 - Epoch [179], Train Loss2: 0.00010010
# Phase 2 - Epoch [180], Train Loss2: 0.00009994
# Phase 2 completed at epoch 180 as Train Loss2 reached 0.00009994
# Phase 3 - Epoch [1], Train Loss1: 0.00009632, Train Loss2: 0.00009498
# Phase 3 - Epoch [2], Train Loss1: 0.00009066, Train Loss2: 0.00008939
# Phase 3 - Epoch [3], Train Loss1: 0.00008613, Train Loss2: 0.00008494
# Phase 3 - Epoch [4], Train Loss1: 0.00008242, Train Loss2: 0.00008126
# Phase 3 - Epoch [5], Train Loss1: 0.00007921, Train Loss2: 0.00007805
# Phase 3 - Epoch [6], Train Loss1: 0.00007643, Train Loss2: 0.00007529
# Phase 3 - Epoch [7], Train Loss1: 0.00007394, Train Loss2: 0.00007289
# Phase 3 - Epoch [8], Train Loss1: 0.00007174, Train Loss2: 0.00007069
# Phase 3 - Epoch [9], Train Loss1: 0.00006986, Train Loss2: 0.00006883
# Phase 3 - Epoch [10], Train Loss1: 0.00006804, Train Loss2: 0.00006702
# Phase 3 - Epoch [11], Train Loss1: 0.00006643, Train Loss2: 0.00006541
# Phase 3 - Epoch [12], Train Loss1: 0.00006490, Train Loss2: 0.00006390
# Phase 3 - Epoch [13], Train Loss1: 0.00006343, Train Loss2: 0.00006245
# Phase 3 - Epoch [14], Train Loss1: 0.00006207, Train Loss2: 0.00006113
# Phase 3 - Epoch [15], Train Loss1: 0.00006083, Train Loss2: 0.00005991
# Phase 3 - Epoch [16], Train Loss1: 0.00005962, Train Loss2: 0.00005871
# Phase 3 - Epoch [17], Train Loss1: 0.00005848, Train Loss2: 0.00005759
# Phase 3 - Epoch [18], Train Loss1: 0.00005743, Train Loss2: 0.00005654
# Phase 3 - Epoch [19], Train Loss1: 0.00005636, Train Loss2: 0.00005548
# Phase 3 - Epoch [20], Train Loss1: 0.00005541, Train Loss2: 0.00005456
# Phase 3 - Epoch [21], Train Loss1: 0.00005444, Train Loss2: 0.00005361
# Phase 3 - Epoch [22], Train Loss1: 0.00005350, Train Loss2: 0.00005268
# Phase 3 - Epoch [23], Train Loss1: 0.00005262, Train Loss2: 0.00005185
# Phase 3 - Epoch [24], Train Loss1: 0.00005178, Train Loss2: 0.00005101
# Phase 3 - Epoch [25], Train Loss1: 0.00005130, Train Loss2: 0.00005050
# Phase 3 - Epoch [26], Train Loss1: 0.00005019, Train Loss2: 0.00004940
# Phase 3 - Epoch [27], Train Loss1: 0.00004941, Train Loss2: 0.00004864
# Phase 3 - Epoch [28], Train Loss1: 0.00004866, Train Loss2: 0.00004792
# Phase 3 - Epoch [29], Train Loss1: 0.00004794, Train Loss2: 0.00004722
# Phase 3 - Epoch [30], Train Loss1: 0.00004730, Train Loss2: 0.00004657
# Phase 3 - Epoch [31], Train Loss1: 0.00004654, Train Loss2: 0.00004584
# Phase 3 - Epoch [32], Train Loss1: 0.00004592, Train Loss2: 0.00004521
# Phase 3 - Epoch [33], Train Loss1: 0.00004531, Train Loss2: 0.00004461
# Phase 3 - Epoch [34], Train Loss1: 0.00004466, Train Loss2: 0.00004398
# Phase 3 - Epoch [35], Train Loss1: 0.00004405, Train Loss2: 0.00004340
# Phase 3 - Epoch [36], Train Loss1: 0.00004349, Train Loss2: 0.00004280
# Phase 3 - Epoch [37], Train Loss1: 0.00004288, Train Loss2: 0.00004221
# Phase 3 - Epoch [38], Train Loss1: 0.00004232, Train Loss2: 0.00004167
# Phase 3 - Epoch [39], Train Loss1: 0.00004180, Train Loss2: 0.00004113
# Phase 3 - Epoch [40], Train Loss1: 0.00004127, Train Loss2: 0.00004064
# Phase 3 - Epoch [41], Train Loss1: 0.00004072, Train Loss2: 0.00004009
# Phase 3 - Epoch [42], Train Loss1: 0.00004024, Train Loss2: 0.00003961
# Phase 3 - Epoch [43], Train Loss1: 0.00003972, Train Loss2: 0.00003912
# Phase 3 - Epoch [44], Train Loss1: 0.00003924, Train Loss2: 0.00003864
# Phase 3 - Epoch [45], Train Loss1: 0.00003879, Train Loss2: 0.00003820
# Phase 3 - Epoch [46], Train Loss1: 0.00003832, Train Loss2: 0.00003774
# Phase 3 - Epoch [47], Train Loss1: 0.00003794, Train Loss2: 0.00003735
# Phase 3 - Epoch [48], Train Loss1: 0.00003746, Train Loss2: 0.00003689
# Phase 3 - Epoch [49], Train Loss1: 0.00003697, Train Loss2: 0.00003641
# Phase 3 - Epoch [50], Train Loss1: 0.00003658, Train Loss2: 0.00003600
# Phase 3 - Epoch [51], Train Loss1: 0.00003617, Train Loss2: 0.00003563
# Phase 3 - Epoch [52], Train Loss1: 0.00003576, Train Loss2: 0.00003522
# Phase 3 - Epoch [53], Train Loss1: 0.00003536, Train Loss2: 0.00003482
# Phase 3 - Epoch [54], Train Loss1: 0.00003498, Train Loss2: 0.00003442
# Phase 3 - Epoch [55], Train Loss1: 0.00003458, Train Loss2: 0.00003405
# Phase 3 - Epoch [56], Train Loss1: 0.00003425, Train Loss2: 0.00003373
# Phase 3 - Epoch [57], Train Loss1: 0.00003387, Train Loss2: 0.00003336
# Phase 3 - Epoch [58], Train Loss1: 0.00003353, Train Loss2: 0.00003302
# Phase 3 - Epoch [59], Train Loss1: 0.00003315, Train Loss2: 0.00003265
# Phase 3 - Epoch [60], Train Loss1: 0.00003281, Train Loss2: 0.00003230
# Phase 3 - Epoch [61], Train Loss1: 0.00003246, Train Loss2: 0.00003197
# Phase 3 - Epoch [62], Train Loss1: 0.00003213, Train Loss2: 0.00003165
# Phase 3 - Epoch [63], Train Loss1: 0.00003185, Train Loss2: 0.00003135
# Phase 3 - Epoch [64], Train Loss1: 0.00003148, Train Loss2: 0.00003102
# Phase 3 - Epoch [65], Train Loss1: 0.00003120, Train Loss2: 0.00003072
# Phase 3 - Epoch [66], Train Loss1: 0.00003088, Train Loss2: 0.00003042
# Phase 3 - Epoch [67], Train Loss1: 0.00003075, Train Loss2: 0.00003027
# Phase 3 - Epoch [68], Train Loss1: 0.00003029, Train Loss2: 0.00002983
# Phase 3 - Epoch [69], Train Loss1: 0.00002999, Train Loss2: 0.00002953
# Phase 3 - Epoch [70], Train Loss1: 0.00002972, Train Loss2: 0.00002926
# Phase 3 - Epoch [71], Train Loss1: 0.00002944, Train Loss2: 0.00002900
# Phase 3 - Epoch [72], Train Loss1: 0.00002917, Train Loss2: 0.00002872
# Phase 3 - Epoch [73], Train Loss1: 0.00002888, Train Loss2: 0.00002845
# Phase 3 - Epoch [74], Train Loss1: 0.00002863, Train Loss2: 0.00002818
# Phase 3 - Epoch [75], Train Loss1: 0.00002835, Train Loss2: 0.00002794
# Phase 3 - Epoch [76], Train Loss1: 0.00002812, Train Loss2: 0.00002769
# Phase 3 - Epoch [77], Train Loss1: 0.00002785, Train Loss2: 0.00002743
# Phase 3 - Epoch [78], Train Loss1: 0.00002762, Train Loss2: 0.00002719
# Phase 3 - Epoch [79], Train Loss1: 0.00002740, Train Loss2: 0.00002699
# Phase 3 - Epoch [80], Train Loss1: 0.00002713, Train Loss2: 0.00002672
# Phase 3 - Epoch [81], Train Loss1: 0.00002702, Train Loss2: 0.00002661
# Phase 3 - Epoch [82], Train Loss1: 0.00002679, Train Loss2: 0.00002637
# Phase 3 - Epoch [83], Train Loss1: 0.00002645, Train Loss2: 0.00002604
# Phase 3 - Epoch [84], Train Loss1: 0.00002623, Train Loss2: 0.00002583
# Phase 3 - Epoch [85], Train Loss1: 0.00002600, Train Loss2: 0.00002561
# Phase 3 - Epoch [86], Train Loss1: 0.00002579, Train Loss2: 0.00002540
# Phase 3 - Epoch [87], Train Loss1: 0.00002557, Train Loss2: 0.00002517
# Phase 3 - Epoch [88], Train Loss1: 0.00002536, Train Loss2: 0.00002498
# Phase 3 - Epoch [89], Train Loss1: 0.00002516, Train Loss2: 0.00002478
# Phase 3 - Epoch [90], Train Loss1: 0.00002494, Train Loss2: 0.00002456
# Phase 3 - Epoch [91], Train Loss1: 0.00002475, Train Loss2: 0.00002438
# Phase 3 - Epoch [92], Train Loss1: 0.00002456, Train Loss2: 0.00002419
# Phase 3 - Epoch [93], Train Loss1: 0.00002438, Train Loss2: 0.00002401
# Phase 3 - Epoch [94], Train Loss1: 0.00002421, Train Loss2: 0.00002384
# Phase 3 - Epoch [95], Train Loss1: 0.00002401, Train Loss2: 0.00002364
# Phase 3 - Epoch [96], Train Loss1: 0.00002381, Train Loss2: 0.00002345
# Phase 3 - Epoch [97], Train Loss1: 0.00002365, Train Loss2: 0.00002330
# Phase 3 - Epoch [98], Train Loss1: 0.00002348, Train Loss2: 0.00002312
# Phase 3 - Epoch [99], Train Loss1: 0.00002329, Train Loss2: 0.00002295
# Phase 3 - Epoch [100], Train Loss1: 0.00002313, Train Loss2: 0.00002279
# Phase 3 - Epoch [101], Train Loss1: 0.00002297, Train Loss2: 0.00002262
# Phase 3 - Epoch [102], Train Loss1: 0.00002284, Train Loss2: 0.00002250
# Phase 3 - Epoch [103], Train Loss1: 0.00002262, Train Loss2: 0.00002229
# Phase 3 - Epoch [104], Train Loss1: 0.00002246, Train Loss2: 0.00002213
# Phase 3 - Epoch [105], Train Loss1: 0.00002231, Train Loss2: 0.00002197
# Phase 3 - Epoch [106], Train Loss1: 0.00002217, Train Loss2: 0.00002184
# Phase 3 - Epoch [107], Train Loss1: 0.00002200, Train Loss2: 0.00002168
# Phase 3 - Epoch [108], Train Loss1: 0.00002185, Train Loss2: 0.00002152
# Phase 3 - Epoch [109], Train Loss1: 0.00002171, Train Loss2: 0.00002138
# Phase 3 - Epoch [110], Train Loss1: 0.00002157, Train Loss2: 0.00002126
# Phase 3 - Epoch [111], Train Loss1: 0.00002143, Train Loss2: 0.00002111
# Phase 3 - Epoch [112], Train Loss1: 0.00002126, Train Loss2: 0.00002095
# Phase 3 - Epoch [113], Train Loss1: 0.00002115, Train Loss2: 0.00002082
# Phase 3 - Epoch [114], Train Loss1: 0.00002100, Train Loss2: 0.00002068
# Phase 3 - Epoch [115], Train Loss1: 0.00002086, Train Loss2: 0.00002055
# Phase 3 - Epoch [116], Train Loss1: 0.00002070, Train Loss2: 0.00002039
# Phase 3 - Epoch [117], Train Loss1: 0.00002061, Train Loss2: 0.00002032
# Phase 3 - Epoch [118], Train Loss1: 0.00002046, Train Loss2: 0.00002016
# Phase 3 - Epoch [119], Train Loss1: 0.00002034, Train Loss2: 0.00002005
# Phase 3 - Epoch [120], Train Loss1: 0.00002021, Train Loss2: 0.00001991
# Phase 3 - Epoch [121], Train Loss1: 0.00002008, Train Loss2: 0.00001979
# Phase 3 - Epoch [122], Train Loss1: 0.00001998, Train Loss2: 0.00001969
# Phase 3 - Epoch [123], Train Loss1: 0.00001986, Train Loss2: 0.00001956
# Phase 3 - Epoch [124], Train Loss1: 0.00001974, Train Loss2: 0.00001945
# Phase 3 - Epoch [125], Train Loss1: 0.00001960, Train Loss2: 0.00001932
# Phase 3 - Epoch [126], Train Loss1: 0.00001952, Train Loss2: 0.00001924
# Phase 3 - Epoch [127], Train Loss1: 0.00001939, Train Loss2: 0.00001910
# Phase 3 - Epoch [128], Train Loss1: 0.00001927, Train Loss2: 0.00001899
# Phase 3 - Epoch [129], Train Loss1: 0.00001917, Train Loss2: 0.00001889
# Phase 3 - Epoch [130], Train Loss1: 0.00001906, Train Loss2: 0.00001878
# Phase 3 - Epoch [131], Train Loss1: 0.00001897, Train Loss2: 0.00001868
# Phase 3 - Epoch [132], Train Loss1: 0.00001885, Train Loss2: 0.00001856
# Phase 3 - Epoch [133], Train Loss1: 0.00001873, Train Loss2: 0.00001847
# Phase 3 - Epoch [134], Train Loss1: 0.00001863, Train Loss2: 0.00001836
# Phase 3 - Epoch [135], Train Loss1: 0.00001854, Train Loss2: 0.00001825
# Phase 3 - Epoch [136], Train Loss1: 0.00001844, Train Loss2: 0.00001816
# Phase 3 - Epoch [137], Train Loss1: 0.00001834, Train Loss2: 0.00001807
# Phase 3 - Epoch [138], Train Loss1: 0.00001823, Train Loss2: 0.00001796
# Phase 3 - Epoch [139], Train Loss1: 0.00001814, Train Loss2: 0.00001788
# Phase 3 - Epoch [140], Train Loss1: 0.00001804, Train Loss2: 0.00001778
# Phase 3 - Epoch [141], Train Loss1: 0.00001795, Train Loss2: 0.00001769
# Phase 3 - Epoch [142], Train Loss1: 0.00001786, Train Loss2: 0.00001761
# Phase 3 - Epoch [143], Train Loss1: 0.00001778, Train Loss2: 0.00001752
# Phase 3 - Epoch [144], Train Loss1: 0.00001768, Train Loss2: 0.00001742
# Phase 3 - Epoch [145], Train Loss1: 0.00001759, Train Loss2: 0.00001734
# Phase 3 - Epoch [146], Train Loss1: 0.00001751, Train Loss2: 0.00001725
# Phase 3 - Epoch [147], Train Loss1: 0.00001743, Train Loss2: 0.00001717
# Phase 3 - Epoch [148], Train Loss1: 0.00001734, Train Loss2: 0.00001709
# Phase 3 - Epoch [149], Train Loss1: 0.00001725, Train Loss2: 0.00001701
# Phase 3 - Epoch [150], Train Loss1: 0.00001717, Train Loss2: 0.00001692
# Phase 3 - Epoch [151], Train Loss1: 0.00001708, Train Loss2: 0.00001683
# Phase 3 - Epoch [152], Train Loss1: 0.00001702, Train Loss2: 0.00001677
# Phase 3 - Epoch [153], Train Loss1: 0.00001694, Train Loss2: 0.00001670
# Phase 3 - Epoch [154], Train Loss1: 0.00001685, Train Loss2: 0.00001661
# Phase 3 - Epoch [155], Train Loss1: 0.00001677, Train Loss2: 0.00001652
# Phase 3 - Epoch [156], Train Loss1: 0.00001669, Train Loss2: 0.00001644
# Phase 3 - Epoch [157], Train Loss1: 0.00001663, Train Loss2: 0.00001638
# Phase 3 - Epoch [158], Train Loss1: 0.00001655, Train Loss2: 0.00001631
# Phase 3 - Epoch [159], Train Loss1: 0.00001656, Train Loss2: 0.00001630
# Phase 3 - Epoch [160], Train Loss1: 0.00001640, Train Loss2: 0.00001616
# Phase 3 - Epoch [161], Train Loss1: 0.00001633, Train Loss2: 0.00001609
# Phase 3 - Epoch [162], Train Loss1: 0.00001626, Train Loss2: 0.00001602
# Phase 3 - Epoch [163], Train Loss1: 0.00001618, Train Loss2: 0.00001595
# Phase 3 - Epoch [164], Train Loss1: 0.00001612, Train Loss2: 0.00001588
# Phase 3 - Epoch [165], Train Loss1: 0.00001605, Train Loss2: 0.00001581
# Phase 3 - Epoch [166], Train Loss1: 0.00001598, Train Loss2: 0.00001575
# Phase 3 - Epoch [167], Train Loss1: 0.00001590, Train Loss2: 0.00001568
# Phase 3 - Epoch [168], Train Loss1: 0.00001585, Train Loss2: 0.00001562
# Phase 3 - Epoch [169], Train Loss1: 0.00001579, Train Loss2: 0.00001556
# Phase 3 - Epoch [170], Train Loss1: 0.00001571, Train Loss2: 0.00001548
# Phase 3 - Epoch [171], Train Loss1: 0.00001564, Train Loss2: 0.00001543
# Phase 3 - Epoch [172], Train Loss1: 0.00001560, Train Loss2: 0.00001537
# Phase 3 - Epoch [173], Train Loss1: 0.00001552, Train Loss2: 0.00001531
# Phase 3 - Epoch [174], Train Loss1: 0.00001546, Train Loss2: 0.00001525
# Phase 3 - Epoch [175], Train Loss1: 0.00001540, Train Loss2: 0.00001519
# Phase 3 - Epoch [176], Train Loss1: 0.00001534, Train Loss2: 0.00001512
# Phase 3 - Epoch [177], Train Loss1: 0.00001528, Train Loss2: 0.00001506
# Phase 3 - Epoch [178], Train Loss1: 0.00001523, Train Loss2: 0.00001501
# Phase 3 - Epoch [179], Train Loss1: 0.00001516, Train Loss2: 0.00001494
# Phase 3 - Epoch [180], Train Loss1: 0.00001511, Train Loss2: 0.00001490
# Phase 3 - Epoch [181], Train Loss1: 0.00001506, Train Loss2: 0.00001484
# Phase 3 - Epoch [182], Train Loss1: 0.00001500, Train Loss2: 0.00001479
# Phase 3 - Epoch [183], Train Loss1: 0.00001494, Train Loss2: 0.00001473
# Phase 3 - Epoch [184], Train Loss1: 0.00001489, Train Loss2: 0.00001467
# Phase 3 - Epoch [185], Train Loss1: 0.00001485, Train Loss2: 0.00001464
# Phase 3 - Epoch [186], Train Loss1: 0.00001479, Train Loss2: 0.00001458
# Phase 3 - Epoch [187], Train Loss1: 0.00001473, Train Loss2: 0.00001452
# Phase 3 - Epoch [188], Train Loss1: 0.00001468, Train Loss2: 0.00001447
# Phase 3 - Epoch [189], Train Loss1: 0.00001464, Train Loss2: 0.00001443
# Phase 3 - Epoch [190], Train Loss1: 0.00001459, Train Loss2: 0.00001438
# Phase 3 - Epoch [191], Train Loss1: 0.00001453, Train Loss2: 0.00001432
# Phase 3 - Epoch [192], Train Loss1: 0.00001447, Train Loss2: 0.00001426
# Phase 3 - Epoch [193], Train Loss1: 0.00001444, Train Loss2: 0.00001423
# Phase 3 - Epoch [194], Train Loss1: 0.00001438, Train Loss2: 0.00001418
# Phase 3 - Epoch [195], Train Loss1: 0.00001434, Train Loss2: 0.00001413
# Phase 3 - Epoch [196], Train Loss1: 0.00001429, Train Loss2: 0.00001408
# Phase 3 - Epoch [197], Train Loss1: 0.00001423, Train Loss2: 0.00001404
# Phase 3 - Epoch [198], Train Loss1: 0.00001418, Train Loss2: 0.00001398
# Phase 3 - Epoch [199], Train Loss1: 0.00001415, Train Loss2: 0.00001395
# Phase 3 - Epoch [200], Train Loss1: 0.00001410, Train Loss2: 0.00001390
# Phase 3 - Epoch [201], Train Loss1: 0.00001406, Train Loss2: 0.00001386
# Phase 3 - Epoch [202], Train Loss1: 0.00001399, Train Loss2: 0.00001380
# Phase 3 - Epoch [203], Train Loss1: 0.00001397, Train Loss2: 0.00001378
# Phase 3 - Epoch [204], Train Loss1: 0.00001393, Train Loss2: 0.00001373
# Phase 3 - Epoch [205], Train Loss1: 0.00001388, Train Loss2: 0.00001368
# Phase 3 - Epoch [206], Train Loss1: 0.00001383, Train Loss2: 0.00001363
# Phase 3 - Epoch [207], Train Loss1: 0.00001380, Train Loss2: 0.00001361
# Phase 3 - Epoch [208], Train Loss1: 0.00001375, Train Loss2: 0.00001355
# Phase 3 - Epoch [209], Train Loss1: 0.00001370, Train Loss2: 0.00001351
# Phase 3 - Epoch [210], Train Loss1: 0.00001366, Train Loss2: 0.00001347
# Phase 3 - Epoch [211], Train Loss1: 0.00001363, Train Loss2: 0.00001344
# Phase 3 - Epoch [212], Train Loss1: 0.00001359, Train Loss2: 0.00001340
# Phase 3 - Epoch [213], Train Loss1: 0.00001355, Train Loss2: 0.00001336
# Phase 3 - Epoch [214], Train Loss1: 0.00001351, Train Loss2: 0.00001332
# Phase 3 - Epoch [215], Train Loss1: 0.00001347, Train Loss2: 0.00001328
# Phase 3 - Epoch [216], Train Loss1: 0.00001341, Train Loss2: 0.00001322
# Phase 3 - Epoch [217], Train Loss1: 0.00001339, Train Loss2: 0.00001320
# Phase 3 - Epoch [218], Train Loss1: 0.00001336, Train Loss2: 0.00001317
# Phase 3 - Epoch [219], Train Loss1: 0.00001333, Train Loss2: 0.00001314
# Phase 3 - Epoch [220], Train Loss1: 0.00001328, Train Loss2: 0.00001309
# Phase 3 - Epoch [221], Train Loss1: 0.00001323, Train Loss2: 0.00001304
# Phase 3 - Epoch [222], Train Loss1: 0.00001321, Train Loss2: 0.00001303
# Phase 3 - Epoch [223], Train Loss1: 0.00001317, Train Loss2: 0.00001298
# Phase 3 - Epoch [224], Train Loss1: 0.00001312, Train Loss2: 0.00001293
# Phase 3 - Epoch [225], Train Loss1: 0.00001309, Train Loss2: 0.00001291
# Phase 3 - Epoch [226], Train Loss1: 0.00001307, Train Loss2: 0.00001288
# Phase 3 - Epoch [227], Train Loss1: 0.00001303, Train Loss2: 0.00001285
# Phase 3 - Epoch [228], Train Loss1: 0.00001299, Train Loss2: 0.00001280
# Phase 3 - Epoch [229], Train Loss1: 0.00001295, Train Loss2: 0.00001277
# Phase 3 - Epoch [230], Train Loss1: 0.00001292, Train Loss2: 0.00001274
# Phase 3 - Epoch [231], Train Loss1: 0.00001289, Train Loss2: 0.00001271
# Phase 3 - Epoch [232], Train Loss1: 0.00001285, Train Loss2: 0.00001268
# Phase 3 - Epoch [233], Train Loss1: 0.00001283, Train Loss2: 0.00001265
# Phase 3 - Epoch [234], Train Loss1: 0.00001279, Train Loss2: 0.00001260
# Phase 3 - Epoch [235], Train Loss1: 0.00001277, Train Loss2: 0.00001259
# Phase 3 - Epoch [236], Train Loss1: 0.00001272, Train Loss2: 0.00001255
# Phase 3 - Epoch [237], Train Loss1: 0.00001268, Train Loss2: 0.00001251
# Phase 3 - Epoch [238], Train Loss1: 0.00001267, Train Loss2: 0.00001249
# Phase 3 - Epoch [239], Train Loss1: 0.00001263, Train Loss2: 0.00001246
# Phase 3 - Epoch [240], Train Loss1: 0.00001261, Train Loss2: 0.00001243
# Phase 3 - Epoch [241], Train Loss1: 0.00001257, Train Loss2: 0.00001240
# Phase 3 - Epoch [242], Train Loss1: 0.00001254, Train Loss2: 0.00001236
# Phase 3 - Epoch [243], Train Loss1: 0.00001251, Train Loss2: 0.00001234
# Phase 3 - Epoch [244], Train Loss1: 0.00001248, Train Loss2: 0.00001231
# Phase 3 - Epoch [245], Train Loss1: 0.00001245, Train Loss2: 0.00001228
# Phase 3 - Epoch [246], Train Loss1: 0.00001243, Train Loss2: 0.00001226
# Phase 3 - Epoch [247], Train Loss1: 0.00001239, Train Loss2: 0.00001222
# Phase 3 - Epoch [248], Train Loss1: 0.00001237, Train Loss2: 0.00001219
# Phase 3 - Epoch [249], Train Loss1: 0.00001234, Train Loss2: 0.00001216
# Phase 3 - Epoch [250], Train Loss1: 0.00001231, Train Loss2: 0.00001214
# Phase 3 - Epoch [251], Train Loss1: 0.00001228, Train Loss2: 0.00001212
# Phase 3 - Epoch [252], Train Loss1: 0.00001225, Train Loss2: 0.00001208
# Phase 3 - Epoch [253], Train Loss1: 0.00001221, Train Loss2: 0.00001204
# Phase 3 - Epoch [254], Train Loss1: 0.00001219, Train Loss2: 0.00001202
# Phase 3 - Epoch [255], Train Loss1: 0.00001218, Train Loss2: 0.00001201
# Phase 3 - Epoch [256], Train Loss1: 0.00001216, Train Loss2: 0.00001199
# Phase 3 - Epoch [257], Train Loss1: 0.00001212, Train Loss2: 0.00001194
# Phase 3 - Epoch [258], Train Loss1: 0.00001211, Train Loss2: 0.00001193
# Phase 3 - Epoch [259], Train Loss1: 0.00001207, Train Loss2: 0.00001190
# Phase 3 - Epoch [260], Train Loss1: 0.00001203, Train Loss2: 0.00001187
# Phase 3 - Epoch [261], Train Loss1: 0.00001201, Train Loss2: 0.00001185
# Phase 3 - Epoch [262], Train Loss1: 0.00001199, Train Loss2: 0.00001182
# Phase 3 - Epoch [263], Train Loss1: 0.00001196, Train Loss2: 0.00001179
# Phase 3 - Epoch [264], Train Loss1: 0.00001193, Train Loss2: 0.00001176
# Phase 3 - Epoch [265], Train Loss1: 0.00001192, Train Loss2: 0.00001176
# Phase 3 - Epoch [266], Train Loss1: 0.00001193, Train Loss2: 0.00001176
# Phase 3 - Epoch [267], Train Loss1: 0.00001186, Train Loss2: 0.00001169
# Phase 3 - Epoch [268], Train Loss1: 0.00001184, Train Loss2: 0.00001167
# Phase 3 - Epoch [269], Train Loss1: 0.00001182, Train Loss2: 0.00001165
# Phase 3 - Epoch [270], Train Loss1: 0.00001179, Train Loss2: 0.00001162
# Phase 3 - Epoch [271], Train Loss1: 0.00001176, Train Loss2: 0.00001160
# Phase 3 - Epoch [272], Train Loss1: 0.00001176, Train Loss2: 0.00001159
# Phase 3 - Epoch [273], Train Loss1: 0.00001171, Train Loss2: 0.00001155
# Phase 3 - Epoch [274], Train Loss1: 0.00001171, Train Loss2: 0.00001154
# Phase 3 - Epoch [275], Train Loss1: 0.00001167, Train Loss2: 0.00001151
# Phase 3 - Epoch [276], Train Loss1: 0.00001165, Train Loss2: 0.00001149
# Phase 3 - Epoch [277], Train Loss1: 0.00001163, Train Loss2: 0.00001147
# Phase 3 - Epoch [278], Train Loss1: 0.00001161, Train Loss2: 0.00001144
# Phase 3 - Epoch [279], Train Loss1: 0.00001158, Train Loss2: 0.00001143
# Phase 3 - Epoch [280], Train Loss1: 0.00001156, Train Loss2: 0.00001141
# Phase 3 - Epoch [281], Train Loss1: 0.00001154, Train Loss2: 0.00001138
# Phase 3 - Epoch [282], Train Loss1: 0.00001152, Train Loss2: 0.00001135
# Phase 3 - Epoch [283], Train Loss1: 0.00001149, Train Loss2: 0.00001134
# Phase 3 - Epoch [284], Train Loss1: 0.00001147, Train Loss2: 0.00001131
# Phase 3 - Epoch [285], Train Loss1: 0.00001145, Train Loss2: 0.00001129
# Phase 3 - Epoch [286], Train Loss1: 0.00001144, Train Loss2: 0.00001128
# Phase 3 - Epoch [287], Train Loss1: 0.00001141, Train Loss2: 0.00001125
# Phase 3 - Epoch [288], Train Loss1: 0.00001139, Train Loss2: 0.00001124
# Phase 3 - Epoch [289], Train Loss1: 0.00001138, Train Loss2: 0.00001122
# Phase 3 - Epoch [290], Train Loss1: 0.00001135, Train Loss2: 0.00001119
# Phase 3 - Epoch [291], Train Loss1: 0.00001134, Train Loss2: 0.00001118
# Phase 3 - Epoch [292], Train Loss1: 0.00001132, Train Loss2: 0.00001116
# Phase 3 - Epoch [293], Train Loss1: 0.00001130, Train Loss2: 0.00001114
# Phase 3 - Epoch [294], Train Loss1: 0.00001128, Train Loss2: 0.00001112
# Phase 3 - Epoch [295], Train Loss1: 0.00001125, Train Loss2: 0.00001109
# Phase 3 - Epoch [296], Train Loss1: 0.00001124, Train Loss2: 0.00001108
# Phase 3 - Epoch [297], Train Loss1: 0.00001121, Train Loss2: 0.00001106
# Phase 3 - Epoch [298], Train Loss1: 0.00001119, Train Loss2: 0.00001103
# Phase 3 - Epoch [299], Train Loss1: 0.00001118, Train Loss2: 0.00001103
# Phase 3 - Epoch [300], Train Loss1: 0.00001115, Train Loss2: 0.00001100
# Phase 3 - Epoch [301], Train Loss1: 0.00001113, Train Loss2: 0.00001098
# Phase 3 - Epoch [302], Train Loss1: 0.00001111, Train Loss2: 0.00001096
# Phase 3 - Epoch [303], Train Loss1: 0.00001110, Train Loss2: 0.00001094
# Phase 3 - Epoch [304], Train Loss1: 0.00001107, Train Loss2: 0.00001092
# Phase 3 - Epoch [305], Train Loss1: 0.00001108, Train Loss2: 0.00001092
# Phase 3 - Epoch [306], Train Loss1: 0.00001105, Train Loss2: 0.00001090
# Phase 3 - Epoch [307], Train Loss1: 0.00001102, Train Loss2: 0.00001087
# Phase 3 - Epoch [308], Train Loss1: 0.00001102, Train Loss2: 0.00001086
# Phase 3 - Epoch [309], Train Loss1: 0.00001099, Train Loss2: 0.00001083
# Phase 3 - Epoch [310], Train Loss1: 0.00001097, Train Loss2: 0.00001082
# Phase 3 - Epoch [311], Train Loss1: 0.00001096, Train Loss2: 0.00001081
# Phase 3 - Epoch [312], Train Loss1: 0.00001095, Train Loss2: 0.00001079
# Phase 3 - Epoch [313], Train Loss1: 0.00001091, Train Loss2: 0.00001076
# Phase 3 - Epoch [314], Train Loss1: 0.00001091, Train Loss2: 0.00001075
# Phase 3 - Epoch [315], Train Loss1: 0.00001089, Train Loss2: 0.00001074
# Phase 3 - Epoch [316], Train Loss1: 0.00001086, Train Loss2: 0.00001071
# Phase 3 - Epoch [317], Train Loss1: 0.00001085, Train Loss2: 0.00001070
# Phase 3 - Epoch [318], Train Loss1: 0.00001083, Train Loss2: 0.00001068
# Phase 3 - Epoch [319], Train Loss1: 0.00001082, Train Loss2: 0.00001068
# Phase 3 - Epoch [320], Train Loss1: 0.00001080, Train Loss2: 0.00001065
# Phase 3 - Epoch [321], Train Loss1: 0.00001078, Train Loss2: 0.00001063
# Phase 3 - Epoch [322], Train Loss1: 0.00001078, Train Loss2: 0.00001062
# Phase 3 - Epoch [323], Train Loss1: 0.00001075, Train Loss2: 0.00001061
# Phase 3 - Epoch [324], Train Loss1: 0.00001073, Train Loss2: 0.00001058
# Phase 3 - Epoch [325], Train Loss1: 0.00001073, Train Loss2: 0.00001058
# Phase 3 - Epoch [326], Train Loss1: 0.00001070, Train Loss2: 0.00001055
# Phase 3 - Epoch [327], Train Loss1: 0.00001068, Train Loss2: 0.00001054
# Phase 3 - Epoch [328], Train Loss1: 0.00001066, Train Loss2: 0.00001052
# Phase 3 - Epoch [329], Train Loss1: 0.00001065, Train Loss2: 0.00001051
# Phase 3 - Epoch [330], Train Loss1: 0.00001063, Train Loss2: 0.00001048
# Phase 3 - Epoch [331], Train Loss1: 0.00001064, Train Loss2: 0.00001049
# Phase 3 - Epoch [332], Train Loss1: 0.00001061, Train Loss2: 0.00001047
# Phase 3 - Epoch [333], Train Loss1: 0.00001059, Train Loss2: 0.00001044
# Phase 3 - Epoch [334], Train Loss1: 0.00001058, Train Loss2: 0.00001043
# Phase 3 - Epoch [335], Train Loss1: 0.00001056, Train Loss2: 0.00001041
# Phase 3 - Epoch [336], Train Loss1: 0.00001054, Train Loss2: 0.00001039
# Phase 3 - Epoch [337], Train Loss1: 0.00001053, Train Loss2: 0.00001038
# Phase 3 - Epoch [338], Train Loss1: 0.00001052, Train Loss2: 0.00001038
# Phase 3 - Epoch [339], Train Loss1: 0.00001050, Train Loss2: 0.00001036
# Phase 3 - Epoch [340], Train Loss1: 0.00001049, Train Loss2: 0.00001035
# Phase 3 - Epoch [341], Train Loss1: 0.00001048, Train Loss2: 0.00001034
# Phase 3 - Epoch [342], Train Loss1: 0.00001046, Train Loss2: 0.00001032
# Phase 3 - Epoch [343], Train Loss1: 0.00001045, Train Loss2: 0.00001031
# Phase 3 - Epoch [344], Train Loss1: 0.00001046, Train Loss2: 0.00001032
# Phase 3 - Epoch [345], Train Loss1: 0.00001043, Train Loss2: 0.00001028
# Phase 3 - Epoch [346], Train Loss1: 0.00001041, Train Loss2: 0.00001026
# Phase 3 - Epoch [347], Train Loss1: 0.00001041, Train Loss2: 0.00001027
# Phase 3 - Epoch [348], Train Loss1: 0.00001037, Train Loss2: 0.00001022
# Phase 3 - Epoch [349], Train Loss1: 0.00001037, Train Loss2: 0.00001022
# Phase 3 - Epoch [350], Train Loss1: 0.00001035, Train Loss2: 0.00001021
# Phase 3 - Epoch [351], Train Loss1: 0.00001033, Train Loss2: 0.00001018
# Phase 3 - Epoch [352], Train Loss1: 0.00001032, Train Loss2: 0.00001018
# Phase 3 - Epoch [353], Train Loss1: 0.00001030, Train Loss2: 0.00001016
# Phase 3 - Epoch [354], Train Loss1: 0.00001029, Train Loss2: 0.00001015
# Phase 3 - Epoch [355], Train Loss1: 0.00001028, Train Loss2: 0.00001015
# Phase 3 - Epoch [356], Train Loss1: 0.00001027, Train Loss2: 0.00001013
# Phase 3 - Epoch [357], Train Loss1: 0.00001026, Train Loss2: 0.00001012
# Phase 3 - Epoch [358], Train Loss1: 0.00001024, Train Loss2: 0.00001009
# Phase 3 - Epoch [359], Train Loss1: 0.00001023, Train Loss2: 0.00001009
# Phase 3 - Epoch [360], Train Loss1: 0.00001022, Train Loss2: 0.00001008
# Phase 3 - Epoch [361], Train Loss1: 0.00001020, Train Loss2: 0.00001006
# Phase 3 - Epoch [362], Train Loss1: 0.00001019, Train Loss2: 0.00001005
# Phase 3 - Epoch [363], Train Loss1: 0.00001019, Train Loss2: 0.00001004
# Phase 3 - Epoch [364], Train Loss1: 0.00001016, Train Loss2: 0.00001002
# Phase 3 - Epoch [365], Train Loss1: 0.00001015, Train Loss2: 0.00001001
# Phase 3 - Epoch [366], Train Loss1: 0.00001013, Train Loss2: 0.00001000
# Phase 3 - Epoch [367], Train Loss1: 0.00001013, Train Loss2: 0.00000998
# Phase 3 - Epoch [368], Train Loss1: 0.00001012, Train Loss2: 0.00000997
# Phase 3 - Epoch [369], Train Loss1: 0.00001010, Train Loss2: 0.00000996
# Phase 3 - Epoch [370], Train Loss1: 0.00001009, Train Loss2: 0.00000995
# Phase 3 - Epoch [371], Train Loss1: 0.00001007, Train Loss2: 0.00000993
# Phase 3 - Epoch [372], Train Loss1: 0.00001006, Train Loss2: 0.00000992
# Phase 3 - Epoch [373], Train Loss1: 0.00001006, Train Loss2: 0.00000992
# Phase 3 - Epoch [374], Train Loss1: 0.00001003, Train Loss2: 0.00000990
# Phase 3 - Epoch [375], Train Loss1: 0.00001003, Train Loss2: 0.00000989
# Phase 3 - Epoch [376], Train Loss1: 0.00001002, Train Loss2: 0.00000988
# Phase 3 - Epoch [377], Train Loss1: 0.00001000, Train Loss2: 0.00000986
# Phase 3 - Epoch [378], Train Loss1: 0.00000999, Train Loss2: 0.00000985
# Phase 3 - Epoch [379], Train Loss1: 0.00000998, Train Loss2: 0.00000984
# Phase 3 - Epoch [380], Train Loss1: 0.00000998, Train Loss2: 0.00000984
# Phase 3 - Epoch [381], Train Loss1: 0.00000996, Train Loss2: 0.00000982
# Phase 3 - Epoch [382], Train Loss1: 0.00000994, Train Loss2: 0.00000981
# Phase 3 - Epoch [383], Train Loss1: 0.00000994, Train Loss2: 0.00000980
# Phase 3 - Epoch [384], Train Loss1: 0.00000993, Train Loss2: 0.00000980
# Phase 3 - Epoch [385], Train Loss1: 0.00000992, Train Loss2: 0.00000978
# Phase 3 - Epoch [386], Train Loss1: 0.00000990, Train Loss2: 0.00000977
# Phase 3 - Epoch [387], Train Loss1: 0.00000990, Train Loss2: 0.00000976
# Phase 3 - Epoch [388], Train Loss1: 0.00000988, Train Loss2: 0.00000974
# Phase 3 - Epoch [389], Train Loss1: 0.00000986, Train Loss2: 0.00000973
# Phase 3 - Epoch [390], Train Loss1: 0.00000985, Train Loss2: 0.00000972
# Phase 3 - Epoch [391], Train Loss1: 0.00000985, Train Loss2: 0.00000971
# Phase 3 - Epoch [392], Train Loss1: 0.00000984, Train Loss2: 0.00000971
# Phase 3 - Epoch [393], Train Loss1: 0.00000982, Train Loss2: 0.00000968
# Phase 3 - Epoch [394], Train Loss1: 0.00000981, Train Loss2: 0.00000967
# Phase 3 - Epoch [395], Train Loss1: 0.00000982, Train Loss2: 0.00000968
# Phase 3 - Epoch [396], Train Loss1: 0.00000979, Train Loss2: 0.00000965
# Phase 3 - Epoch [397], Train Loss1: 0.00000978, Train Loss2: 0.00000965
# Phase 3 - Epoch [398], Train Loss1: 0.00000978, Train Loss2: 0.00000964
# Phase 3 - Epoch [399], Train Loss1: 0.00000976, Train Loss2: 0.00000963
# Phase 3 - Epoch [400], Train Loss1: 0.00000974, Train Loss2: 0.00000961
# Phase 3 - Epoch [401], Train Loss1: 0.00000974, Train Loss2: 0.00000960
# Phase 3 - Epoch [402], Train Loss1: 0.00000972, Train Loss2: 0.00000959
# Phase 3 - Epoch [403], Train Loss1: 0.00000972, Train Loss2: 0.00000958
# Phase 3 - Epoch [404], Train Loss1: 0.00000971, Train Loss2: 0.00000957
# Phase 3 - Epoch [405], Train Loss1: 0.00000971, Train Loss2: 0.00000957
# Phase 3 - Epoch [406], Train Loss1: 0.00000970, Train Loss2: 0.00000956
# Phase 3 - Epoch [407], Train Loss1: 0.00000967, Train Loss2: 0.00000954
# Phase 3 - Epoch [408], Train Loss1: 0.00000967, Train Loss2: 0.00000954
# Phase 3 - Epoch [409], Train Loss1: 0.00000966, Train Loss2: 0.00000953
# Phase 3 - Epoch [410], Train Loss1: 0.00000964, Train Loss2: 0.00000951
# Phase 3 - Epoch [411], Train Loss1: 0.00000963, Train Loss2: 0.00000950
# Phase 3 - Epoch [412], Train Loss1: 0.00000963, Train Loss2: 0.00000949
# Phase 3 - Epoch [413], Train Loss1: 0.00000961, Train Loss2: 0.00000948
# Phase 3 - Epoch [414], Train Loss1: 0.00000960, Train Loss2: 0.00000947
# Phase 3 - Epoch [415], Train Loss1: 0.00000960, Train Loss2: 0.00000946
# Phase 3 - Epoch [416], Train Loss1: 0.00000958, Train Loss2: 0.00000945
# Phase 3 - Epoch [417], Train Loss1: 0.00000958, Train Loss2: 0.00000944
# Phase 3 - Epoch [418], Train Loss1: 0.00000956, Train Loss2: 0.00000943
# Phase 3 - Epoch [419], Train Loss1: 0.00000956, Train Loss2: 0.00000942
# Phase 3 - Epoch [420], Train Loss1: 0.00000955, Train Loss2: 0.00000942
# Phase 3 - Epoch [421], Train Loss1: 0.00000954, Train Loss2: 0.00000941
# Phase 3 - Epoch [422], Train Loss1: 0.00000953, Train Loss2: 0.00000939
# Phase 3 - Epoch [423], Train Loss1: 0.00000953, Train Loss2: 0.00000940
# Phase 3 - Epoch [424], Train Loss1: 0.00000951, Train Loss2: 0.00000938
# Phase 3 - Epoch [425], Train Loss1: 0.00000949, Train Loss2: 0.00000936
# Phase 3 - Epoch [426], Train Loss1: 0.00000948, Train Loss2: 0.00000935
# Phase 3 - Epoch [427], Train Loss1: 0.00000948, Train Loss2: 0.00000935
# Phase 3 - Epoch [428], Train Loss1: 0.00000947, Train Loss2: 0.00000934
# Phase 3 - Epoch [429], Train Loss1: 0.00000946, Train Loss2: 0.00000933
# Phase 3 - Epoch [430], Train Loss1: 0.00000946, Train Loss2: 0.00000933
# Phase 3 - Epoch [431], Train Loss1: 0.00000944, Train Loss2: 0.00000932
# Phase 3 - Epoch [432], Train Loss1: 0.00000943, Train Loss2: 0.00000930
# Phase 3 - Epoch [433], Train Loss1: 0.00000942, Train Loss2: 0.00000929
# Phase 3 - Epoch [434], Train Loss1: 0.00000942, Train Loss2: 0.00000928
# Phase 3 - Epoch [435], Train Loss1: 0.00000940, Train Loss2: 0.00000927
# Phase 3 - Epoch [436], Train Loss1: 0.00000940, Train Loss2: 0.00000927
# Phase 3 - Epoch [437], Train Loss1: 0.00000938, Train Loss2: 0.00000925
# Phase 3 - Epoch [438], Train Loss1: 0.00000938, Train Loss2: 0.00000925
# Phase 3 - Epoch [439], Train Loss1: 0.00000936, Train Loss2: 0.00000924
# Phase 3 - Epoch [440], Train Loss1: 0.00000937, Train Loss2: 0.00000924
# Phase 3 - Epoch [441], Train Loss1: 0.00000935, Train Loss2: 0.00000922
# Phase 3 - Epoch [442], Train Loss1: 0.00000934, Train Loss2: 0.00000921
# Phase 3 - Epoch [443], Train Loss1: 0.00000933, Train Loss2: 0.00000920
# Phase 3 - Epoch [444], Train Loss1: 0.00000932, Train Loss2: 0.00000920
# Phase 3 - Epoch [445], Train Loss1: 0.00000932, Train Loss2: 0.00000919
# Phase 3 - Epoch [446], Train Loss1: 0.00000932, Train Loss2: 0.00000919
# Phase 3 - Epoch [447], Train Loss1: 0.00000930, Train Loss2: 0.00000918
# Phase 3 - Epoch [448], Train Loss1: 0.00000929, Train Loss2: 0.00000917
# Phase 3 - Epoch [449], Train Loss1: 0.00000929, Train Loss2: 0.00000916
# Phase 3 - Epoch [450], Train Loss1: 0.00000927, Train Loss2: 0.00000915
# Phase 3 - Epoch [451], Train Loss1: 0.00000927, Train Loss2: 0.00000914
# Phase 3 - Epoch [452], Train Loss1: 0.00000926, Train Loss2: 0.00000913
# Phase 3 - Epoch [453], Train Loss1: 0.00000925, Train Loss2: 0.00000912
# Phase 3 - Epoch [454], Train Loss1: 0.00000924, Train Loss2: 0.00000912
# Phase 3 - Epoch [455], Train Loss1: 0.00000925, Train Loss2: 0.00000912
# Phase 3 - Epoch [456], Train Loss1: 0.00000924, Train Loss2: 0.00000911
# Phase 3 - Epoch [457], Train Loss1: 0.00000922, Train Loss2: 0.00000909
# Phase 3 - Epoch [458], Train Loss1: 0.00000921, Train Loss2: 0.00000908
# Phase 3 - Epoch [459], Train Loss1: 0.00000920, Train Loss2: 0.00000907
# Phase 3 - Epoch [460], Train Loss1: 0.00000919, Train Loss2: 0.00000907
# Phase 3 - Epoch [461], Train Loss1: 0.00000918, Train Loss2: 0.00000906
# Phase 3 - Epoch [462], Train Loss1: 0.00000918, Train Loss2: 0.00000906
# Phase 3 - Epoch [463], Train Loss1: 0.00000917, Train Loss2: 0.00000905
# Phase 3 - Epoch [464], Train Loss1: 0.00000916, Train Loss2: 0.00000903
# Phase 3 - Epoch [465], Train Loss1: 0.00000916, Train Loss2: 0.00000903
# Phase 3 - Epoch [466], Train Loss1: 0.00000914, Train Loss2: 0.00000902
# Phase 3 - Epoch [467], Train Loss1: 0.00000914, Train Loss2: 0.00000901
# Phase 3 - Epoch [468], Train Loss1: 0.00000912, Train Loss2: 0.00000900
# Phase 3 - Epoch [469], Train Loss1: 0.00000912, Train Loss2: 0.00000900
# Phase 3 - Epoch [470], Train Loss1: 0.00000911, Train Loss2: 0.00000899
# Phase 3 - Epoch [471], Train Loss1: 0.00000910, Train Loss2: 0.00000898
# Phase 3 - Epoch [472], Train Loss1: 0.00000909, Train Loss2: 0.00000897
# Phase 3 - Epoch [473], Train Loss1: 0.00000909, Train Loss2: 0.00000897
# Phase 3 - Epoch [474], Train Loss1: 0.00000908, Train Loss2: 0.00000896
# Phase 3 - Epoch [475], Train Loss1: 0.00000907, Train Loss2: 0.00000894
# Phase 3 - Epoch [476], Train Loss1: 0.00000907, Train Loss2: 0.00000894
# Phase 3 - Epoch [477], Train Loss1: 0.00000905, Train Loss2: 0.00000893
# Phase 3 - Epoch [478], Train Loss1: 0.00000905, Train Loss2: 0.00000893
# Phase 3 - Epoch [479], Train Loss1: 0.00000904, Train Loss2: 0.00000892
# Phase 3 - Epoch [480], Train Loss1: 0.00000903, Train Loss2: 0.00000891
# Phase 3 - Epoch [481], Train Loss1: 0.00000902, Train Loss2: 0.00000890
# Phase 3 - Epoch [482], Train Loss1: 0.00000901, Train Loss2: 0.00000889
# Phase 3 - Epoch [483], Train Loss1: 0.00000901, Train Loss2: 0.00000888
# Phase 3 - Epoch [484], Train Loss1: 0.00000900, Train Loss2: 0.00000888
# Phase 3 - Epoch [485], Train Loss1: 0.00000901, Train Loss2: 0.00000889
# Phase 3 - Epoch [486], Train Loss1: 0.00000899, Train Loss2: 0.00000886
# Phase 3 - Epoch [487], Train Loss1: 0.00000899, Train Loss2: 0.00000886
# Phase 3 - Epoch [488], Train Loss1: 0.00000897, Train Loss2: 0.00000885
# Phase 3 - Epoch [489], Train Loss1: 0.00000897, Train Loss2: 0.00000884
# Phase 3 - Epoch [490], Train Loss1: 0.00000897, Train Loss2: 0.00000884
# Phase 3 - Epoch [491], Train Loss1: 0.00000896, Train Loss2: 0.00000883
# Phase 3 - Epoch [492], Train Loss1: 0.00000894, Train Loss2: 0.00000882
# Phase 3 - Epoch [493], Train Loss1: 0.00000894, Train Loss2: 0.00000881
# Phase 3 - Epoch [494], Train Loss1: 0.00000893, Train Loss2: 0.00000881
# Phase 3 - Epoch [495], Train Loss1: 0.00000892, Train Loss2: 0.00000880
# Phase 3 - Epoch [496], Train Loss1: 0.00000892, Train Loss2: 0.00000880
# Phase 3 - Epoch [497], Train Loss1: 0.00000891, Train Loss2: 0.00000879
# Phase 3 - Epoch [498], Train Loss1: 0.00000891, Train Loss2: 0.00000878
# Phase 3 - Epoch [499], Train Loss1: 0.00000889, Train Loss2: 0.00000877
# Phase 3 - Epoch [500], Train Loss1: 0.00000888, Train Loss2: 0.00000876
# Phase 3 - Epoch [501], Train Loss1: 0.00000889, Train Loss2: 0.00000876
# Phase 3 - Epoch [502], Train Loss1: 0.00000888, Train Loss2: 0.00000876
# Phase 3 - Epoch [503], Train Loss1: 0.00000887, Train Loss2: 0.00000875
# Phase 3 - Epoch [504], Train Loss1: 0.00000886, Train Loss2: 0.00000874
# Phase 3 - Epoch [505], Train Loss1: 0.00000886, Train Loss2: 0.00000873
# Phase 3 - Epoch [506], Train Loss1: 0.00000885, Train Loss2: 0.00000873
# Phase 3 - Epoch [507], Train Loss1: 0.00000885, Train Loss2: 0.00000872
# Phase 3 - Epoch [508], Train Loss1: 0.00000883, Train Loss2: 0.00000871
# Phase 3 - Epoch [509], Train Loss1: 0.00000883, Train Loss2: 0.00000871
# Phase 3 - Epoch [510], Train Loss1: 0.00000882, Train Loss2: 0.00000870
# Phase 3 - Epoch [511], Train Loss1: 0.00000882, Train Loss2: 0.00000870
# Phase 3 - Epoch [512], Train Loss1: 0.00000881, Train Loss2: 0.00000869
# Phase 3 - Epoch [513], Train Loss1: 0.00000881, Train Loss2: 0.00000869
# Phase 3 - Epoch [514], Train Loss1: 0.00000879, Train Loss2: 0.00000867
# Phase 3 - Epoch [515], Train Loss1: 0.00000879, Train Loss2: 0.00000868
# Phase 3 - Epoch [516], Train Loss1: 0.00000878, Train Loss2: 0.00000866
# Phase 3 - Epoch [517], Train Loss1: 0.00000879, Train Loss2: 0.00000867
# Phase 3 - Epoch [518], Train Loss1: 0.00000876, Train Loss2: 0.00000864
# Phase 3 - Epoch [519], Train Loss1: 0.00000877, Train Loss2: 0.00000865
# Phase 3 - Epoch [520], Train Loss1: 0.00000876, Train Loss2: 0.00000864
# Phase 3 - Epoch [521], Train Loss1: 0.00000875, Train Loss2: 0.00000863
# Phase 3 - Epoch [522], Train Loss1: 0.00000874, Train Loss2: 0.00000862
# Phase 3 - Epoch [523], Train Loss1: 0.00000874, Train Loss2: 0.00000862
# Phase 3 - Epoch [524], Train Loss1: 0.00000873, Train Loss2: 0.00000861
# Phase 3 - Epoch [525], Train Loss1: 0.00000873, Train Loss2: 0.00000861
# Phase 3 - Epoch [526], Train Loss1: 0.00000872, Train Loss2: 0.00000860
# Phase 3 - Epoch [527], Train Loss1: 0.00000871, Train Loss2: 0.00000859
# Phase 3 - Epoch [528], Train Loss1: 0.00000869, Train Loss2: 0.00000857
# Phase 3 - Epoch [529], Train Loss1: 0.00000869, Train Loss2: 0.00000858
# Phase 3 - Epoch [530], Train Loss1: 0.00000869, Train Loss2: 0.00000857
# Phase 3 - Epoch [531], Train Loss1: 0.00000868, Train Loss2: 0.00000857
# Phase 3 - Epoch [532], Train Loss1: 0.00000868, Train Loss2: 0.00000856
# Phase 3 - Epoch [533], Train Loss1: 0.00000867, Train Loss2: 0.00000855
# Phase 3 - Epoch [534], Train Loss1: 0.00000866, Train Loss2: 0.00000854
# Phase 3 - Epoch [535], Train Loss1: 0.00000865, Train Loss2: 0.00000854
# Phase 3 - Epoch [536], Train Loss1: 0.00000864, Train Loss2: 0.00000853
# Phase 3 - Epoch [537], Train Loss1: 0.00000865, Train Loss2: 0.00000853
# Phase 3 - Epoch [538], Train Loss1: 0.00000864, Train Loss2: 0.00000852
# Phase 3 - Epoch [539], Train Loss1: 0.00000862, Train Loss2: 0.00000850
# Phase 3 - Epoch [540], Train Loss1: 0.00000863, Train Loss2: 0.00000851
# Phase 3 - Epoch [541], Train Loss1: 0.00000862, Train Loss2: 0.00000850
# Phase 3 - Epoch [542], Train Loss1: 0.00000862, Train Loss2: 0.00000850
# Phase 3 - Epoch [543], Train Loss1: 0.00000861, Train Loss2: 0.00000850
# Phase 3 - Epoch [544], Train Loss1: 0.00000860, Train Loss2: 0.00000848
# ...
# Phase 3 - Epoch [1492], Train Loss1: 0.00000546, Train Loss2: 0.00000538
# Phase 3 - Epoch [1493], Train Loss1: 0.00000545, Train Loss2: 0.00000538
# Phase 3 - Epoch [1494], Train Loss1: 0.00000545, Train Loss2: 0.00000538
# Phase 3 - Epoch [1495], Train Loss1: 0.00000545, Train Loss2: 0.00000537
# Phase 3 - Epoch [1496], Train Loss1: 0.00000545, Train Loss2: 0.00000537
# Phase 3 - Epoch [1497], Train Loss1: 0.00000544, Train Loss2: 0.00000536
# Phase 3 - Epoch [1498], Train Loss1: 0.00000545, Train Loss2: 0.00000537
# Phase 3 - Epoch [1499], Train Loss1: 0.00000544, Train Loss2: 0.00000536
# Phase 3 - Epoch [1500], Train Loss1: 0.00000544, Train Loss2: 0.00000536
# Phase 3 - Epoch [1501], Train Loss1: 0.00000543, Train Loss2: 0.00000536
# Phase 3 - Epoch [1502], Train Loss1: 0.00000543, Train Loss2: 0.00000535
# Phase 3 - Epoch [1503], Train Loss1: 0.00000543, Train Loss2: 0.00000535
# Phase 3 - Epoch [1504], Train Loss1: 0.00000543, Train Loss2: 0.00000535
# Phase 3 - Epoch [1505], Train Loss1: 0.00000542, Train Loss2: 0.00000535
# Phase 3 - Epoch [1506], Train Loss1: 0.00000542, Train Loss2: 0.00000535
# Phase 3 - Epoch [1507], Train Loss1: 0.00000543, Train Loss2: 0.00000535
# Phase 3 - Epoch [1508], Train Loss1: 0.00000541, Train Loss2: 0.00000534
# Phase 3 - Epoch [1509], Train Loss1: 0.00000542, Train Loss2: 0.00000534
# Phase 3 - Epoch [1510], Train Loss1: 0.00000541, Train Loss2: 0.00000534
# Phase 3 - Epoch [1511], Train Loss1: 0.00000541, Train Loss2: 0.00000534
# Phase 3 - Epoch [1512], Train Loss1: 0.00000540, Train Loss2: 0.00000533
# Phase 3 - Epoch [1513], Train Loss1: 0.00000540, Train Loss2: 0.00000533
# Phase 3 - Epoch [1514], Train Loss1: 0.00000541, Train Loss2: 0.00000533
# Phase 3 - Epoch [1515], Train Loss1: 0.00000540, Train Loss2: 0.00000533
# Phase 3 - Epoch [1516], Train Loss1: 0.00000540, Train Loss2: 0.00000532
# Phase 3 - Epoch [1517], Train Loss1: 0.00000540, Train Loss2: 0.00000533
# Phase 3 - Epoch [1518], Train Loss1: 0.00000539, Train Loss2: 0.00000532
# Phase 3 - Epoch [1519], Train Loss1: 0.00000539, Train Loss2: 0.00000531
# Phase 3 - Epoch [1520], Train Loss1: 0.00000538, Train Loss2: 0.00000532
# Phase 3 - Epoch [1521], Train Loss1: 0.00000538, Train Loss2: 0.00000531
# Phase 3 - Epoch [1522], Train Loss1: 0.00000538, Train Loss2: 0.00000531
# Phase 3 - Epoch [1523], Train Loss1: 0.00000538, Train Loss2: 0.00000531
# Phase 3 - Epoch [1524], Train Loss1: 0.00000538, Train Loss2: 0.00000531
# Phase 3 - Epoch [1525], Train Loss1: 0.00000537, Train Loss2: 0.00000530
# Phase 3 - Epoch [1526], Train Loss1: 0.00000537, Train Loss2: 0.00000530
# Phase 3 - Epoch [1527], Train Loss1: 0.00000537, Train Loss2: 0.00000530
# Phase 3 - Epoch [1528], Train Loss1: 0.00000536, Train Loss2: 0.00000529
# Phase 3 - Epoch [1529], Train Loss1: 0.00000537, Train Loss2: 0.00000529
# Phase 3 - Epoch [1530], Train Loss1: 0.00000536, Train Loss2: 0.00000529
# Phase 3 - Epoch [1531], Train Loss1: 0.00000536, Train Loss2: 0.00000529
# Phase 3 - Epoch [1532], Train Loss1: 0.00000535, Train Loss2: 0.00000528
# Phase 3 - Epoch [1533], Train Loss1: 0.00000536, Train Loss2: 0.00000528
# Phase 3 - Epoch [1534], Train Loss1: 0.00000536, Train Loss2: 0.00000528
# Phase 3 - Epoch [1535], Train Loss1: 0.00000535, Train Loss2: 0.00000528
# Phase 3 - Epoch [1536], Train Loss1: 0.00000535, Train Loss2: 0.00000528
# Phase 3 - Epoch [1537], Train Loss1: 0.00000535, Train Loss2: 0.00000527
# Phase 3 - Epoch [1538], Train Loss1: 0.00000535, Train Loss2: 0.00000527
# Phase 3 - Epoch [1539], Train Loss1: 0.00000534, Train Loss2: 0.00000527
# Phase 3 - Epoch [1540], Train Loss1: 0.00000534, Train Loss2: 0.00000527
# Phase 3 - Epoch [1541], Train Loss1: 0.00000534, Train Loss2: 0.00000527
# Phase 3 - Epoch [1542], Train Loss1: 0.00000534, Train Loss2: 0.00000527
# Phase 3 - Epoch [1543], Train Loss1: 0.00000534, Train Loss2: 0.00000526
# Phase 3 - Epoch [1544], Train Loss1: 0.00000533, Train Loss2: 0.00000525
# Phase 3 - Epoch [1545], Train Loss1: 0.00000533, Train Loss2: 0.00000525
# Phase 3 - Epoch [1546], Train Loss1: 0.00000532, Train Loss2: 0.00000525
# Phase 3 - Epoch [1547], Train Loss1: 0.00000532, Train Loss2: 0.00000525
# Phase 3 - Epoch [1548], Train Loss1: 0.00000532, Train Loss2: 0.00000525
# Phase 3 - Epoch [1549], Train Loss1: 0.00000532, Train Loss2: 0.00000525
# Phase 3 - Epoch [1550], Train Loss1: 0.00000531, Train Loss2: 0.00000524
# Phase 3 - Epoch [1551], Train Loss1: 0.00000532, Train Loss2: 0.00000524
# Phase 3 - Epoch [1552], Train Loss1: 0.00000531, Train Loss2: 0.00000524
# Phase 3 - Epoch [1553], Train Loss1: 0.00000531, Train Loss2: 0.00000524
# Phase 3 - Epoch [1554], Train Loss1: 0.00000531, Train Loss2: 0.00000523
# Phase 3 - Epoch [1555], Train Loss1: 0.00000530, Train Loss2: 0.00000523
# Phase 3 - Epoch [1556], Train Loss1: 0.00000530, Train Loss2: 0.00000523
# Phase 3 - Epoch [1557], Train Loss1: 0.00000531, Train Loss2: 0.00000523
# Phase 3 - Epoch [1558], Train Loss1: 0.00000530, Train Loss2: 0.00000522
# Phase 3 - Epoch [1559], Train Loss1: 0.00000530, Train Loss2: 0.00000522
# Phase 3 - Epoch [1560], Train Loss1: 0.00000529, Train Loss2: 0.00000522
# Phase 3 - Epoch [1561], Train Loss1: 0.00000529, Train Loss2: 0.00000522
# Phase 3 - Epoch [1562], Train Loss1: 0.00000529, Train Loss2: 0.00000522
# Phase 3 - Epoch [1563], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1564], Train Loss1: 0.00000529, Train Loss2: 0.00000522
# Phase 3 - Epoch [1565], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1566], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1567], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1568], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1569], Train Loss1: 0.00000528, Train Loss2: 0.00000521
# Phase 3 - Epoch [1570], Train Loss1: 0.00000527, Train Loss2: 0.00000520
# Phase 3 - Epoch [1571], Train Loss1: 0.00000527, Train Loss2: 0.00000520
# Phase 3 - Epoch [1572], Train Loss1: 0.00000526, Train Loss2: 0.00000519
# Phase 3 - Epoch [1573], Train Loss1: 0.00000526, Train Loss2: 0.00000520
# Phase 3 - Epoch [1574], Train Loss1: 0.00000526, Train Loss2: 0.00000519
# Phase 3 - Epoch [1575], Train Loss1: 0.00000526, Train Loss2: 0.00000518
# Phase 3 - Epoch [1576], Train Loss1: 0.00000525, Train Loss2: 0.00000518
# Phase 3 - Epoch [1577], Train Loss1: 0.00000525, Train Loss2: 0.00000518
# Phase 3 - Epoch [1578], Train Loss1: 0.00000525, Train Loss2: 0.00000518
# Phase 3 - Epoch [1579], Train Loss1: 0.00000524, Train Loss2: 0.00000518
# Phase 3 - Epoch [1580], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1581], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1582], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1583], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1584], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1585], Train Loss1: 0.00000524, Train Loss2: 0.00000517
# Phase 3 - Epoch [1586], Train Loss1: 0.00000523, Train Loss2: 0.00000516
# Phase 3 - Epoch [1587], Train Loss1: 0.00000524, Train Loss2: 0.00000516
# Phase 3 - Epoch [1588], Train Loss1: 0.00000523, Train Loss2: 0.00000516
# Phase 3 - Epoch [1589], Train Loss1: 0.00000523, Train Loss2: 0.00000516
# Phase 3 - Epoch [1590], Train Loss1: 0.00000522, Train Loss2: 0.00000515
# Phase 3 - Epoch [1591], Train Loss1: 0.00000522, Train Loss2: 0.00000515
# Phase 3 - Epoch [1592], Train Loss1: 0.00000522, Train Loss2: 0.00000515
# Phase 3 - Epoch [1593], Train Loss1: 0.00000522, Train Loss2: 0.00000515
# Phase 3 - Epoch [1594], Train Loss1: 0.00000521, Train Loss2: 0.00000514
# Phase 3 - Epoch [1595], Train Loss1: 0.00000521, Train Loss2: 0.00000514
# Phase 3 - Epoch [1596], Train Loss1: 0.00000521, Train Loss2: 0.00000514
# Phase 3 - Epoch [1597], Train Loss1: 0.00000521, Train Loss2: 0.00000514
# Phase 3 - Epoch [1598], Train Loss1: 0.00000520, Train Loss2: 0.00000513
# Phase 3 - Epoch [1599], Train Loss1: 0.00000520, Train Loss2: 0.00000513
# Phase 3 - Epoch [1600], Train Loss1: 0.00000520, Train Loss2: 0.00000513
# Phase 3 - Epoch [1601], Train Loss1: 0.00000520, Train Loss2: 0.00000512
# Phase 3 - Epoch [1602], Train Loss1: 0.00000519, Train Loss2: 0.00000512
# Phase 3 - Epoch [1603], Train Loss1: 0.00000520, Train Loss2: 0.00000513
# Phase 3 - Epoch [1604], Train Loss1: 0.00000519, Train Loss2: 0.00000512
# Phase 3 - Epoch [1605], Train Loss1: 0.00000519, Train Loss2: 0.00000512
# Phase 3 - Epoch [1606], Train Loss1: 0.00000518, Train Loss2: 0.00000511
# Phase 3 - Epoch [1607], Train Loss1: 0.00000519, Train Loss2: 0.00000512
# Phase 3 - Epoch [1608], Train Loss1: 0.00000518, Train Loss2: 0.00000511
# Phase 3 - Epoch [1609], Train Loss1: 0.00000518, Train Loss2: 0.00000511
# Phase 3 - Epoch [1610], Train Loss1: 0.00000518, Train Loss2: 0.00000511
# Phase 3 - Epoch [1611], Train Loss1: 0.00000517, Train Loss2: 0.00000511
# Phase 3 - Epoch [1612], Train Loss1: 0.00000517, Train Loss2: 0.00000510
# Phase 3 - Epoch [1613], Train Loss1: 0.00000517, Train Loss2: 0.00000510
# Phase 3 - Epoch [1614], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1615], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1616], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1617], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1618], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1619], Train Loss1: 0.00000516, Train Loss2: 0.00000509
# Phase 3 - Epoch [1620], Train Loss1: 0.00000515, Train Loss2: 0.00000508
# Phase 3 - Epoch [1621], Train Loss1: 0.00000515, Train Loss2: 0.00000508
# Phase 3 - Epoch [1622], Train Loss1: 0.00000515, Train Loss2: 0.00000508
# Phase 3 - Epoch [1623], Train Loss1: 0.00000514, Train Loss2: 0.00000507
# Phase 3 - Epoch [1624], Train Loss1: 0.00000515, Train Loss2: 0.00000507
# Phase 3 - Epoch [1625], Train Loss1: 0.00000515, Train Loss2: 0.00000508
# Phase 3 - Epoch [1626], Train Loss1: 0.00000514, Train Loss2: 0.00000507
# Phase 3 - Epoch [1627], Train Loss1: 0.00000514, Train Loss2: 0.00000507
# Phase 3 - Epoch [1628], Train Loss1: 0.00000514, Train Loss2: 0.00000507
# Phase 3 - Epoch [1629], Train Loss1: 0.00000513, Train Loss2: 0.00000506
# Phase 3 - Epoch [1630], Train Loss1: 0.00000513, Train Loss2: 0.00000506
# Phase 3 - Epoch [1631], Train Loss1: 0.00000513, Train Loss2: 0.00000506
# Phase 3 - Epoch [1632], Train Loss1: 0.00000512, Train Loss2: 0.00000505
# Phase 3 - Epoch [1633], Train Loss1: 0.00000513, Train Loss2: 0.00000506
# Phase 3 - Epoch [1634], Train Loss1: 0.00000512, Train Loss2: 0.00000505
# Phase 3 - Epoch [1635], Train Loss1: 0.00000512, Train Loss2: 0.00000505
# Phase 3 - Epoch [1636], Train Loss1: 0.00000512, Train Loss2: 0.00000505
# Phase 3 - Epoch [1637], Train Loss1: 0.00000512, Train Loss2: 0.00000505
# Phase 3 - Epoch [1638], Train Loss1: 0.00000511, Train Loss2: 0.00000504
# Phase 3 - Epoch [1639], Train Loss1: 0.00000511, Train Loss2: 0.00000504
# Phase 3 - Epoch [1640], Train Loss1: 0.00000511, Train Loss2: 0.00000504
# Phase 3 - Epoch [1641], Train Loss1: 0.00000510, Train Loss2: 0.00000503
# Phase 3 - Epoch [1642], Train Loss1: 0.00000510, Train Loss2: 0.00000503
# Phase 3 - Epoch [1643], Train Loss1: 0.00000511, Train Loss2: 0.00000504
# Phase 3 - Epoch [1644], Train Loss1: 0.00000510, Train Loss2: 0.00000503
# Phase 3 - Epoch [1645], Train Loss1: 0.00000510, Train Loss2: 0.00000503
# Phase 3 - Epoch [1646], Train Loss1: 0.00000510, Train Loss2: 0.00000502
# Phase 3 - Epoch [1647], Train Loss1: 0.00000509, Train Loss2: 0.00000502
# Phase 3 - Epoch [1648], Train Loss1: 0.00000510, Train Loss2: 0.00000503
# Phase 3 - Epoch [1649], Train Loss1: 0.00000509, Train Loss2: 0.00000502
# Phase 3 - Epoch [1650], Train Loss1: 0.00000508, Train Loss2: 0.00000501
# Phase 3 - Epoch [1651], Train Loss1: 0.00000508, Train Loss2: 0.00000501
# Phase 3 - Epoch [1652], Train Loss1: 0.00000508, Train Loss2: 0.00000502
# Phase 3 - Epoch [1653], Train Loss1: 0.00000508, Train Loss2: 0.00000501
# Phase 3 - Epoch [1654], Train Loss1: 0.00000508, Train Loss2: 0.00000501
# Phase 3 - Epoch [1655], Train Loss1: 0.00000507, Train Loss2: 0.00000500
# Phase 3 - Epoch [1656], Train Loss1: 0.00000507, Train Loss2: 0.00000500
# Phase 3 - Epoch [1657], Train Loss1: 0.00000507, Train Loss2: 0.00000500
# Phase 3 - Epoch [1658], Train Loss1: 0.00000507, Train Loss2: 0.00000500
# Phase 3 - Epoch [1659], Train Loss1: 0.00000506, Train Loss2: 0.00000500
# Phase 3 - Epoch [1660], Train Loss1: 0.00000506, Train Loss2: 0.00000499
# Phase 3 - Epoch [1661], Train Loss1: 0.00000506, Train Loss2: 0.00000499
# Phase 3 - Epoch [1662], Train Loss1: 0.00000506, Train Loss2: 0.00000499
# Phase 3 - Epoch [1663], Train Loss1: 0.00000505, Train Loss2: 0.00000499
# Phase 3 - Epoch [1664], Train Loss1: 0.00000505, Train Loss2: 0.00000498
# Phase 3 - Epoch [1665], Train Loss1: 0.00000505, Train Loss2: 0.00000498
# Phase 3 - Epoch [1666], Train Loss1: 0.00000504, Train Loss2: 0.00000498
# Phase 3 - Epoch [1667], Train Loss1: 0.00000505, Train Loss2: 0.00000498
# Phase 3 - Epoch [1668], Train Loss1: 0.00000504, Train Loss2: 0.00000498
# Phase 3 - Epoch [1669], Train Loss1: 0.00000504, Train Loss2: 0.00000497
# Phase 3 - Epoch [1670], Train Loss1: 0.00000504, Train Loss2: 0.00000497
# Phase 3 - Epoch [1671], Train Loss1: 0.00000503, Train Loss2: 0.00000497
# Phase 3 - Epoch [1672], Train Loss1: 0.00000504, Train Loss2: 0.00000497
# Phase 3 - Epoch [1673], Train Loss1: 0.00000504, Train Loss2: 0.00000497
# Phase 3 - Epoch [1674], Train Loss1: 0.00000503, Train Loss2: 0.00000496
# Phase 3 - Epoch [1675], Train Loss1: 0.00000503, Train Loss2: 0.00000496
# Phase 3 - Epoch [1676], Train Loss1: 0.00000503, Train Loss2: 0.00000496
# Phase 3 - Epoch [1677], Train Loss1: 0.00000502, Train Loss2: 0.00000495
# Phase 3 - Epoch [1678], Train Loss1: 0.00000502, Train Loss2: 0.00000495
# Phase 3 - Epoch [1679], Train Loss1: 0.00000502, Train Loss2: 0.00000495
# Phase 3 - Epoch [1680], Train Loss1: 0.00000502, Train Loss2: 0.00000495
# Phase 3 - Epoch [1681], Train Loss1: 0.00000501, Train Loss2: 0.00000495
# Phase 3 - Epoch [1682], Train Loss1: 0.00000501, Train Loss2: 0.00000494
# Phase 3 - Epoch [1683], Train Loss1: 0.00000501, Train Loss2: 0.00000494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 92
#      90 optimizer1.zero_grad()
#      91 loss1 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
# ---> 92 loss1.backward(retain_graph=True)
#      93 optimizer1.step()
#      94 epoch_loss1 += loss1.item()
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/.local/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/.local/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
def plot_losses(train_losses1_phase1, train_losses1_phase3, train_losses2_phase2, train_losses2_phase3):
    # Création de la figure et des axes
    fig, axs = plt.subplots(2, 2, figsize=(14, 10))
    
    # Phase 1 - Train Loss 1
    epochs_phase1 = range(1, len(train_losses1_phase1) + 1)
    axs[0, 0].plot(epochs_phase1, train_losses1_phase1, label='Train Loss 1 (Phase 1)')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].set_ylim(0, 0.002)
    axs[0, 0].set_title('Training Loss 1 (Phase 1)')
    axs[0, 0].legend()

    # Phase 2 - Train Loss 2
    epochs_phase2 = range(1, len(train_losses2_phase2) + 1)
    axs[0, 1].plot(epochs_phase2, train_losses2_phase2, label='Train Loss 2 (Phase 2)')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 0].set_ylim(0, 0.002)
    axs[0, 1].set_title('Training Loss 2 (Phase 2)')
    axs[0, 1].legend()
    
    # Phase 3 - Train Loss 1 et 2
    epochs_phase3 = range(1, len(train_losses1_phase3) + 1)
    axs[1, 0].plot(epochs_phase3, train_losses1_phase3, label='Train Loss 1 (Phase 3)')
    axs[1, 0].plot(epochs_phase3, train_losses2_phase3, label='Train Loss 2 (Phase 3)')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].set_xlim(0, len(train_losses1_phase3))
    axs[1, 0].set_ylim(0, 10.e-5)
    axs[1, 0].set_title('Training Loss 1 et 2 (Phase 3)')
    axs[1, 0].legend()

    # Zoom sur Phase 3 - Train Loss 1 et 2
    axs[1, 1].plot(epochs_phase3, train_losses1_phase3, label='Train Loss 1 (Phase 3)')
    axs[1, 1].plot(epochs_phase3, train_losses2_phase3, label='Train Loss 2 (Phase 3)')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Loss')
    axs[1, 1].set_title('Zoom on Training Loss 1 et 2 (Phase 3)')
    axs[1, 1].set_xlim(0, len(train_losses1_phase3))
    axs[1, 1].set_ylim(0, 10.e-5)
    axs[1, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
# Affichage des pertes
plot_losses(train_losses1_phase1, train_losses1_phase3, train_losses2_phase2, train_losses2_phase3)

# %% [markdown]
# #### Version avec arrêt au nb d'itération donnée en entrée

# %%
# Boucle d'entraînement
num_epochs = 150

# Listes pour enregistrer les valeurs de perte
train_losses1 = []
train_losses2 = []
#val_losses1 = []
#val_losses2 = []

# Boucle d'entraînement
for epoch in range(num_epochs):
    model.train()
    epoch_loss1 = 0
    epoch_loss2 = 0
    for batch in loader: #train_loader:
        X1 = batch['X1']
        X2 = batch['X2']
        delta_ssh = batch['Delta_ssh_model']
        w_init1 = batch['w_init1']

        # Initialisation
        if epoch <= 50:
            y1, _ = model(X1, X2)
            optimizer1.zero_grad()
            loss1 = criterion(delta_ssh.unsqueeze(1), w_init1.unsqueeze(1) - y1)
            loss1.backward(retain_graph=True)
            optimizer1.step()
            epoch_loss1 += loss1.item()

        elif epoch > 50 and epoch <= 100:
            y1, y2 = model(X1, X2)
            optimizer2.zero_grad()
            loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
            loss2.backward()
            optimizer2.step()
            epoch_loss2 += loss2.item()

        else:
            # Forward pass for both sub-models
            y1, y2 = model(X1, X2)

            # Calcul de la perte pour SubModel1
            optimizer1.zero_grad()
            loss1 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
            loss1.backward(retain_graph=True)
            optimizer1.step()
            epoch_loss1 += loss1.item()

            # Forward pass for both sub-models
            y1, y2 = model(X1, X2)
            # Calcul de la perte pour SubModel2
            optimizer2.zero_grad()
            loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
            loss2.backward()
            optimizer2.step()
            epoch_loss2 += loss2.item()

    avg_train_loss1 = epoch_loss1 / len(loader)#len(train_loader)
    avg_train_loss2 = epoch_loss2 / len(loader)#len(train_loader)
    train_losses1.append(avg_train_loss1)
    train_losses2.append(avg_train_loss2)
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss1: {avg_train_loss1:.8f}, Train Loss2: {avg_train_loss2:.8f}')

    ## Validation
    # model.eval()
    # val_loss1 = 0
    # val_loss2 = 0
    # with torch.no_grad():
    #     for batch in val_loader:
    #         X1 = batch['X1']
    #         X2 = batch['X2']
    #         delta_ssh = batch['Delta_ssh_model']
    #         y1, y2 = model(X1, X2)
    #         loss1 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
    #         loss2 = criterion(delta_ssh.unsqueeze(1), y2 - y1)
    #         val_loss1 += loss1.item()
    #         val_loss2 += loss2.item()

    # avg_val_loss1 = val_loss1 / len(val_loader)
    # avg_val_loss2 = val_loss2 / len(val_loader)
    # val_losses1.append(avg_val_loss1)
    # val_losses2.append(avg_val_loss2)
    # print(f'Epoch [{epoch+1}/{num_epochs}], Val Loss1: {avg_val_loss1:.4f}, Val Loss2: {avg_val_loss2:.4f}')
# Out:
# Epoch [1/150], Train Loss1: 0.00151994, Train Loss2: 0.00000000
# Epoch [2/150], Train Loss1: 0.00022144, Train Loss2: 0.00000000
# Epoch [3/150], Train Loss1: 0.00012751, Train Loss2: 0.00000000
# Epoch [4/150], Train Loss1: 0.00008601, Train Loss2: 0.00000000
# Epoch [5/150], Train Loss1: 0.00006266, Train Loss2: 0.00000000
# Epoch [6/150], Train Loss1: 0.00004834, Train Loss2: 0.00000000
# Epoch [7/150], Train Loss1: 0.00003896, Train Loss2: 0.00000000
# Epoch [8/150], Train Loss1: 0.00003266, Train Loss2: 0.00000000
# Epoch [9/150], Train Loss1: 0.00002817, Train Loss2: 0.00000000
# Epoch [10/150], Train Loss1: 0.00002486, Train Loss2: 0.00000000
# Epoch [11/150], Train Loss1: 0.00002234, Train Loss2: 0.00000000
# Epoch [12/150], Train Loss1: 0.00002040, Train Loss2: 0.00000000
# Epoch [13/150], Train Loss1: 0.00001886, Train Loss2: 0.00000000
# Epoch [14/150], Train Loss1: 0.00001759, Train Loss2: 0.00000000
# Epoch [15/150], Train Loss1: 0.00001646, Train Loss2: 0.00000000
# Epoch [16/150], Train Loss1: 0.00001560, Train Loss2: 0.00000000
# Epoch [17/150], Train Loss1: 0.00001483, Train Loss2: 0.00000000
# Epoch [18/150], Train Loss1: 0.00001413, Train Loss2: 0.00000000
# Epoch [19/150], Train Loss1: 0.00001353, Train Loss2: 0.00000000
# Epoch [20/150], Train Loss1: 0.00001297, Train Loss2: 0.00000000
# Epoch [21/150], Train Loss1: 0.00001248, Train Loss2: 0.00000000
# Epoch [22/150], Train Loss1: 0.00001203, Train Loss2: 0.00000000
# Epoch [23/150], Train Loss1: 0.00001164, Train Loss2: 0.00000000
# Epoch [24/150], Train Loss1: 0.00001125, Train Loss2: 0.00000000
# Epoch [25/150], Train Loss1: 0.00001089, Train Loss2: 0.00000000
# Epoch [26/150], Train Loss1: 0.00001059, Train Loss2: 0.00000000
# Epoch [27/150], Train Loss1: 0.00001028, Train Loss2: 0.00000000
# Epoch [28/150], Train Loss1: 0.00001002, Train Loss2: 0.00000000
# Epoch [29/150], Train Loss1: 0.00000974, Train Loss2: 0.00000000
# Epoch [30/150], Train Loss1: 0.00000949, Train Loss2: 0.00000000
# Epoch [31/150], Train Loss1: 0.00000926, Train Loss2: 0.00000000
# Epoch [32/150], Train Loss1: 0.00000902, Train Loss2: 0.00000000
# Epoch [33/150], Train Loss1: 0.00000881, Train Loss2: 0.00000000
# Epoch [34/150], Train Loss1: 0.00000861, Train Loss2: 0.00000000
# Epoch [35/150], Train Loss1: 0.00000840, Train Loss2: 0.00000000
# Epoch [36/150], Train Loss1: 0.00000823, Train Loss2: 0.00000000
# Epoch [37/150], Train Loss1: 0.00000805, Train Loss2: 0.00000000
# Epoch [38/150], Train Loss1: 0.00000788, Train Loss2: 0.00000000
# Epoch [39/150], Train Loss1: 0.00000771, Train Loss2: 0.00000000
# Epoch [40/150], Train Loss1: 0.00000755, Train Loss2: 0.00000000
# Epoch [41/150], Train Loss1: 0.00000740, Train Loss2: 0.00000000
# Epoch [42/150], Train Loss1: 0.00000725, Train Loss2: 0.00000000
# Epoch [43/150], Train Loss1: 0.00000712, Train Loss2: 0.00000000
# Epoch [44/150], Train Loss1: 0.00000700, Train Loss2: 0.00000000
# Epoch [45/150], Train Loss1: 0.00000685, Train Loss2: 0.00000000
# Epoch [46/150], Train Loss1: 0.00000673, Train Loss2: 0.00000000
# Epoch [47/150], Train Loss1: 0.00000660, Train Loss2: 0.00000000
# Epoch [48/150], Train Loss1: 0.00000650, Train Loss2: 0.00000000
# Epoch [49/150], Train Loss1: 0.00000636, Train Loss2: 0.00000000
# Epoch [50/150], Train Loss1: 0.00000627, Train Loss2: 0.00000000
# Epoch [51/150], Train Loss1: 0.00000616, Train Loss2: 0.00000000
# Epoch [52/150], Train Loss1: 0.00000000, Train Loss2: 0.00193099
# Epoch [53/150], Train Loss1: 0.00000000, Train Loss2: 0.00008334
# Epoch [54/150], Train Loss1: 0.00000000, Train Loss2: 0.00005310
# Epoch [55/150], Train Loss1: 0.00000000, Train Loss2: 0.00004090
# Epoch [56/150], Train Loss1: 0.00000000, Train Loss2: 0.00003418
# Epoch [57/150], Train Loss1: 0.00000000, Train Loss2: 0.00002976
# Epoch [58/150], Train Loss1: 0.00000000, Train Loss2: 0.00002674
# Epoch [59/150], Train Loss1: 0.00000000, Train Loss2: 0.00002447
# Epoch [60/150], Train Loss1: 0.00000000, Train Loss2: 0.00002279
# Epoch [61/150], Train Loss1: 0.00000000, Train Loss2: 0.00002145
# Epoch [62/150], Train Loss1: 0.00000000, Train Loss2: 0.00002042
# Epoch [63/150], Train Loss1: 0.00000000, Train Loss2: 0.00001953
# Epoch [64/150], Train Loss1: 0.00000000, Train Loss2: 0.00001879
# Epoch [65/150], Train Loss1: 0.00000000, Train Loss2: 0.00001818
# Epoch [66/150], Train Loss1: 0.00000000, Train Loss2: 0.00001765
# Epoch [67/150], Train Loss1: 0.00000000, Train Loss2: 0.00001721
# Epoch [68/150], Train Loss1: 0.00000000, Train Loss2: 0.00001677
# Epoch [69/150], Train Loss1: 0.00000000, Train Loss2: 0.00001638
# Epoch [70/150], Train Loss1: 0.00000000, Train Loss2: 0.00001605
# Epoch [71/150], Train Loss1: 0.00000000, Train Loss2: 0.00001571
# Epoch [72/150], Train Loss1: 0.00000000, Train Loss2: 0.00001545
# Epoch [73/150], Train Loss1: 0.00000000, Train Loss2: 0.00001516
# Epoch [74/150], Train Loss1: 0.00000000, Train Loss2: 0.00001490
# Epoch [75/150], Train Loss1: 0.00000000, Train Loss2: 0.00001469
# Epoch [76/150], Train Loss1: 0.00000000, Train Loss2: 0.00001444
# Epoch [77/150], Train Loss1: 0.00000000, Train Loss2: 0.00001425
# Epoch [78/150], Train Loss1: 0.00000000, Train Loss2: 0.00001399
# Epoch [79/150], Train Loss1: 0.00000000, Train Loss2: 0.00001382
# Epoch [80/150], Train Loss1: 0.00000000, Train Loss2: 0.00001367
# Epoch [81/150], Train Loss1: 0.00000000, Train Loss2: 0.00001348
# Epoch [82/150], Train Loss1: 0.00000000, Train Loss2: 0.00001331
# Epoch [83/150], Train Loss1: 0.00000000, Train Loss2: 0.00001313
# Epoch [84/150], Train Loss1: 0.00000000, Train Loss2: 0.00001299
# Epoch [85/150], Train Loss1: 0.00000000, Train Loss2: 0.00001285
# Epoch [86/150], Train Loss1: 0.00000000, Train Loss2: 0.00001273
# Epoch [87/150], Train Loss1: 0.00000000, Train Loss2: 0.00001259
# Epoch [88/150], Train Loss1: 0.00000000, Train Loss2: 0.00001246
# Epoch [89/150], Train Loss1: 0.00000000, Train Loss2: 0.00001232
# Epoch [90/150], Train Loss1: 0.00000000, Train Loss2: 0.00001218
# Epoch [91/150], Train Loss1: 0.00000000, Train Loss2: 0.00001207
# Epoch [92/150], Train Loss1: 0.00000000, Train Loss2: 0.00001196
# Epoch [93/150], Train Loss1: 0.00000000, Train Loss2: 0.00001186
# Epoch [94/150], Train Loss1: 0.00000000, Train Loss2: 0.00001173
# Epoch [95/150], Train Loss1: 0.00000000, Train Loss2: 0.00001164
# Epoch [96/150], Train Loss1: 0.00000000, Train Loss2: 0.00001153
# Epoch [97/150], Train Loss1: 0.00000000, Train Loss2: 0.00001144
# Epoch [98/150], Train Loss1: 0.00000000, Train Loss2: 0.00001136
# Epoch [99/150], Train Loss1: 0.00000000, Train Loss2: 0.00001124
# Epoch [100/150], Train Loss1: 0.00000000, Train Loss2: 0.00001119
# Epoch [101/150], Train Loss1: 0.00000000, Train Loss2: 0.00001109
# Epoch [102/150], Train Loss1: 0.00001103, Train Loss2: 0.00001026
# Epoch [103/150], Train Loss1: 0.00001084, Train Loss2: 0.00001008
# Epoch [104/150], Train Loss1: 0.00001066, Train Loss2: 0.00000991
# Epoch [105/150], Train Loss1: 0.00001051, Train Loss2: 0.00000976
# Epoch [106/150], Train Loss1: 0.00001036, Train Loss2: 0.00000960
# Epoch [107/150], Train Loss1: 0.00001021, Train Loss2: 0.00000948
# Epoch [108/150], Train Loss1: 0.00001005, Train Loss2: 0.00000932
# Epoch [109/150], Train Loss1: 0.00000988, Train Loss2: 0.00000916
# Epoch [110/150], Train Loss1: 0.00000972, Train Loss2: 0.00000902
# Epoch [111/150], Train Loss1: 0.00000962, Train Loss2: 0.00000894
# Epoch [112/150], Train Loss1: 0.00000949, Train Loss2: 0.00000879
# Epoch [113/150], Train Loss1: 0.00000934, Train Loss2: 0.00000866
# Epoch [114/150], Train Loss1: 0.00000921, Train Loss2: 0.00000855
# Epoch [115/150], Train Loss1: 0.00000909, Train Loss2: 0.00000843
# Epoch [116/150], Train Loss1: 0.00000897, Train Loss2: 0.00000832
# Epoch [117/150], Train Loss1: 0.00000887, Train Loss2: 0.00000823
# Epoch [118/150], Train Loss1: 0.00000874, Train Loss2: 0.00000813
# Epoch [119/150], Train Loss1: 0.00000862, Train Loss2: 0.00000801
# Epoch [120/150], Train Loss1: 0.00000852, Train Loss2: 0.00000790
# Epoch [121/150], Train Loss1: 0.00000842, Train Loss2: 0.00000780
# Epoch [122/150], Train Loss1: 0.00000830, Train Loss2: 0.00000773
# Epoch [123/150], Train Loss1: 0.00000821, Train Loss2: 0.00000761
# Epoch [124/150], Train Loss1: 0.00000810, Train Loss2: 0.00000753
# Epoch [125/150], Train Loss1: 0.00000799, Train Loss2: 0.00000741
# Epoch [126/150], Train Loss1: 0.00000792, Train Loss2: 0.00000735
# Epoch [127/150], Train Loss1: 0.00000781, Train Loss2: 0.00000725
# Epoch [128/150], Train Loss1: 0.00000774, Train Loss2: 0.00000718
# Epoch [129/150], Train Loss1: 0.00000764, Train Loss2: 0.00000707
# Epoch [130/150], Train Loss1: 0.00000757, Train Loss2: 0.00000700
# Epoch [131/150], Train Loss1: 0.00000747, Train Loss2: 0.00000694
# Epoch [132/150], Train Loss1: 0.00000741, Train Loss2: 0.00000686
# Epoch [133/150], Train Loss1: 0.00000732, Train Loss2: 0.00000677
# Epoch [134/150], Train Loss1: 0.00000723, Train Loss2: 0.00000671
# Epoch [135/150], Train Loss1: 0.00000714, Train Loss2: 0.00000663
# Epoch [136/150], Train Loss1: 0.00000708, Train Loss2: 0.00000656
# Epoch [137/150], Train Loss1: 0.00000700, Train Loss2: 0.00000649
# Epoch [138/150], Train Loss1: 0.00000692, Train Loss2: 0.00000642
# Epoch [139/150], Train Loss1: 0.00000686, Train Loss2: 0.00000636
# Epoch [140/150], Train Loss1: 0.00000680, Train Loss2: 0.00000630
# Epoch [141/150], Train Loss1: 0.00000672, Train Loss2: 0.00000623
# Epoch [142/150], Train Loss1: 0.00000664, Train Loss2: 0.00000617
# Epoch [143/150], Train Loss1: 0.00000659, Train Loss2: 0.00000610
# Epoch [144/150], Train Loss1: 0.00000651, Train Loss2: 0.00000604
# Epoch [145/150], Train Loss1: 0.00000646, Train Loss2: 0.00000599
# Epoch [146/150], Train Loss1: 0.00000639, Train Loss2: 0.00000593
# Epoch [147/150], Train Loss1: 0.00000634, Train Loss2: 0.00000589
# Epoch [148/150], Train Loss1: 0.00000627, Train Loss2: 0.00000582
# Epoch [149/150], Train Loss1: 0.00000623, Train Loss2: 0.00000576
# Epoch [150/150], Train Loss1: 0.00000618, Train Loss2: 0.00000572

# %%
def plot_losses(num_epochs, train_losses1, train_losses2): #val_losses1, train_losses2, val_losses2):
    epochs = range(num_epochs)

    fig, axs = plt.subplots(2, 2, figsize=(14, 10))

    # Tracer les pertes pour Train Loss 1 et Val Loss 1
    axs[0, 0].plot(epochs, train_losses1, label='Train Loss 1')
    # axs[0, 0].plot(epochs, val_losses1, label='Val Loss 1')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].set_title('Training and Validation Loss 1')
    axs[0, 0].legend()

    # Tracer les pertes pour Train Loss 2 et Val Loss 2
    axs[0, 1].plot(epochs, train_losses2, label='Train Loss 2')
    # axs[0, 1].plot(epochs, val_losses2, label='Val Loss 2')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 1].set_title('Training and Validation Loss 2')
    axs[0, 1].legend()

    # Tracer les pertes zoomées pour Train Loss 1 et Val Loss 1
    axs[1, 0].plot(epochs, train_losses1, label='Train Loss 1')
    # axs[1, 0].plot(epochs, val_losses1, label='Val Loss 1')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].set_title('Zoom on Training and Validation Loss 1')
    axs[1, 0].set_xlim(0, num_epochs)
    axs[1, 0].set_ylim(0, 1.e-4)
    axs[1, 0].legend()

    # Tracer les pertes zoomées pour Train Loss 2 et Val Loss 2
    axs[1, 1].plot(epochs, train_losses2, label='Train Loss 2')
    # axs[1, 1].plot(epochs, val_losses2, label='Val Loss 2')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('Loss')
    axs[1, 1].set_title('Zoom on Training and Validation Loss 2')
    axs[1, 1].set_xlim(0, num_epochs)
    axs[1, 1].set_ylim(0, 1.e-4)
    axs[1, 1].legend()

    plt.tight_layout()
    plt.show()

# %%
plot_losses(num_epochs, train_losses1, train_losses2)

# %% [markdown]
# #### Sauvegarder le modèle

# %%
torch.save(model, '/data/SSB_ETU/HLAFARGUE/S6JTEX/neural_networkmodel_sinthetic_aplha_0pt01.pth')

# %% [markdown]
# ## Prediction

# %%
# Calculer les prédictions
pred1_values = []
pred2_values = []
x1_values = []
x2_values = []

# Mettre le modèle en mode évaluation
model.eval()
with torch.no_grad():
    for batch in loader: #test_loader:
          X1 = batch['X1']
          X2 = batch['X2']
          # Prédiction de X1 et X2 normalisées
          pred1, pred2 = model(X1,X2)
          pred1_values.append(pred1)
          pred2_values.append(pred2)
          # Remettre les prédictions à l'échelle d'origine
          x1_values.append(X1 * scale_1 + mean_1)
          x2_values.append(X2 * scale_2 + mean_2)

# Convertir les listes en arrays
pred1_values = np.concatenate(pred1_values)
pred2_values = np.concatenate(pred2_values)
x1_values = np.concatenate(x1_values)
x2_values = np.concatenate(x2_values)

# %%
# Calculer les différences
true_y1 = function(x1_values[:, 0], x1_values[:, 1]).reshape(-1, 1)
diff_y1 = pred1_values - true_y1

true_y2 = function(x2_values[:, 0], x2_values[:, 1]).reshape(-1, 1)
diff_y2 = pred2_values - true_y2

# %%
# Comparer les prédictions aux vraies valeurs
accuracy1 = np.mean(np.isclose(pred1_values, true_y1, atol=0.001)) * 100
accuracy2 = np.mean(np.isclose(pred2_values, true_y2, atol=0.001)) * 100
print(f'Accuracy1: {accuracy1:.2f} %')
print(f'Accuracy2: {accuracy2:.2f} %')
# Out:
# Accuracy1: 0.72 %
# Accuracy2: 0.46 %

# %%
# Tracer les prédictions et les différences
def plot_predictions_and_differences(x1_values, pred_y1, true_y1, diff_y1, x2_values, pred_y2, true_y2, diff_y2):
    fig, axs = plt.subplots(2, 2, figsize=(16, 12))

    # Fixer les limites de l'échelle
    vmin, vmax = -0.35, 0
    diff_min, diff_max = -0.05, 0.05

    # Saturer les valeurs des prédictions et des différences
    pred_y1_clipped = np.clip(pred_y1, vmin, vmax)
    pred_y2_clipped = np.clip(pred_y2, vmin, vmax)
    diff_y1_clipped = np.clip(diff_y1, diff_min, diff_max)
    diff_y2_clipped = np.clip(diff_y2, diff_min, diff_max)

    # Définir les niveaux pour les contours
    pred_levels = np.linspace(vmin, vmax, 15)
    diff_levels = np.linspace(diff_min, diff_max, 15)

    # Prédictions phi1
    cnf1 = axs[0, 0].tricontourf(x1_values[:,0], x1_values[:,1], pred_y1_clipped.ravel(), levels=pred_levels, cmap='viridis', vmin=vmin, vmax=vmax)
    cn1 = axs[0, 0].tricontour(x1_values[:,0], x1_values[:,1], pred_y1_clipped.ravel(), levels=pred_levels, linewidths=0.5, colors='white')
    cbar1 = fig.colorbar(cnf1, ax=axs[0, 0])
    cbar1.set_ticks(np.linspace(vmin, vmax, num=8))
    cbar1.set_ticklabels([f"{x:.2f}" for x in np.linspace(vmin, vmax, num=8)])
    axs[0, 0].set_xlabel('WS')
    axs[0, 0].set_ylabel('SWH')
    axs[0, 0].set_title('Prédictions phi1')

    # Différences phi1
    cnf2 = axs[0, 1].tricontourf(x1_values[:,0], x1_values[:,1], diff_y1_clipped.ravel(), levels=diff_levels, cmap='coolwarm', vmin=diff_min, vmax=diff_max)
    cn2 = axs[0, 1].tricontour(x1_values[:,0], x1_values[:,1], diff_y1_clipped.ravel(), levels=diff_levels, linewidths=0.5, colors='white')
    cbar2 = fig.colorbar(cnf2, ax=axs[0, 1])
    cbar2.set_ticks(np.linspace(diff_min, diff_max, num=8))
    cbar2.set_ticklabels([f"{x:.2f}" for x in np.linspace(diff_min, diff_max, num=8)])
    axs[0, 1].set_xlabel('WS')
    axs[0, 1].set_ylabel('SWH')
    axs[0, 1].set_title('Différences entre les prédictions phi1 et les valeurs réelles')

    # Prédictions phi2
    cnf3 = axs[1, 0].tricontourf(x2_values[:,0], x2_values[:,1], pred_y2_clipped.ravel(), levels=pred_levels, cmap='viridis', vmin=vmin, vmax=vmax)
    cn3 = axs[1, 0].tricontour(x2_values[:,0], x2_values[:,1], pred_y2_clipped.ravel(), levels=pred_levels, linewidths=0.5, colors='white')
    cbar3 = fig.colorbar(cnf3, ax=axs[1, 0])
    cbar3.set_ticks(np.linspace(vmin, vmax, num=8))
    cbar3.set_ticklabels([f"{x:.2f}" for x in np.linspace(vmin, vmax, num=8)])
    axs[1, 0].set_xlabel('WS')
    axs[1, 0].set_ylabel('SWH')
    axs[1, 0].set_title('Prédictions phi2')

    # Différences phi2
    cnf4 = axs[1, 1].tricontourf(x2_values[:,0], x2_values[:,1], diff_y2_clipped.ravel(), levels=diff_levels, cmap='coolwarm', vmin=diff_min, vmax=diff_max)
    cn4 = axs[1, 1].tricontour(x2_values[:,0], x2_values[:,1], diff_y2_clipped.ravel(), levels=diff_levels, linewidths=0.5, colors='white')
    cbar4 = fig.colorbar(cnf4, ax=axs[1, 1])
    cbar4.set_ticks(np.linspace(diff_min, diff_max, num=8))
    cbar4.set_ticklabels([f"{x:.2f}" for x in np.linspace(diff_min, diff_max, num=8)])
    axs[1, 1].set_xlabel('WS')
    axs[1, 1].set_ylabel('SWH')
    axs[1, 1].set_title('Différences entre les prédictions phi2 et les valeurs réelles')

    plt.tight_layout()
    plt.show()

# %%
plot_predictions_and_differences(x1_values, pred1_values, true_y1, diff_y1, x2_values, pred2_values, true_y2, diff_y2)
